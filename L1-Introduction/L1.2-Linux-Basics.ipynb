# %% [markdown]
# # Linux Basics
#
# ## Feng Li
#
# ### Central University of Finance and Economics
#
# ### [feng.li@cufe.edu.cn](feng.li@cufe.edu.cn)
# ### Course home page: [https://feng.li/distcomp](https://feng.li/distcomp)

# %% [markdown]
# # Why Linux?
#
#
#
# - Linux is a free, open-source operating system.
#
# - All most all of distributed software are offered with Linux distributions.

# %% [markdown]
# # How much do we need to know about Linux?
#
# - Login to a Linux server
#
# - Navigation with basic Linux shell commands
#
# - File Manipulation
#
# - Use an editor within a Linux server

# %% [markdown]
# ## Login to a Linux server
#
# - Windows user, you need an SSH client
#
#     - PuTTY or
#
#     - Xshell
#
#
# - Mac or Linux user, use the system terminal to login to the server
#
#       ssh yourusername@your.server.address

# %% [markdown]
# ## Navigation with basic Linux shell commands
#
# - Once you have logged into the server, a few things you could do

# %%
whoami
# Out:
# lifeng

# %%
pwd
# Out:
# /home/lifeng/lectures/L1-Introduction

# %%
ls
# Out:
# figures
# L1.1-Introduction-to-Distributed-Computing .ipynb
# L1.2-Linux-Basic.ipynb
# L1.3-Introduction-to-Hadoop.ipynb
# lifeng.txt

# %%
ls -htla
# Out:
# total 48K
# drwxr-xr-x 4 lifeng lifeng 4.0K Feb 12 23:36 .
# -rw-r--r-- 1 lifeng lifeng 2.9K Feb 12 23:36 L1.2-Linux-Basic.ipynb
# -rw-r--r-- 1 lifeng lifeng  23K Feb 12 23:19 L1.3-Introduction-to-Hadoop.ipynb
# -rw-r--r-- 1 lifeng lifeng 1.8K Feb 12 23:17 L1.1-Introduction-to-Distributed-Computing .ipynb
# drwxr-xr-x 2 lifeng lifeng 4.0K Feb 12 23:16 .ipynb_checkpoints
# drwxr-xr-x 2 lifeng lifeng 4.0K Feb 12 23:02 figures
# drwxr-xr-x 4 lifeng lifeng 4.0K Feb 12 23:00 ..

# %%
cat /etc/passwd
# Out:
# root:x:0:0:root:/root:/bin/bash
# bin:x:1:1:bin:/bin:/sbin/nologin
# daemon:x:2:2:daemon:/sbin:/sbin/nologin
# adm:x:3:4:adm:/var/adm:/sbin/nologin
# lp:x:4:7:lp:/var/spool/lpd:/sbin/nologin
# sync:x:5:0:sync:/sbin:/bin/sync
# shutdown:x:6:0:shutdown:/sbin:/sbin/shutdown
# halt:x:7:0:halt:/sbin:/sbin/halt
# mail:x:8:12:mail:/var/spool/mail:/sbin/nologin
# operator:x:11:0:operator:/root:/sbin/nologin
# games:x:12:100:games:/usr/games:/sbin/nologin
# ftp:x:14:50:FTP User:/var/ftp:/sbin/nologin
# nobody:x:99:99:Nobody:/:/sbin/nologin
# systemd-network:x:192:192:systemd Network Management:/:/sbin/nologin
# dbus:x:81:81:System message bus:/:/sbin/nologin
# polkitd:x:999:997:User for polkitd:/:/sbin/nologin
# postfix:x:89:89::/var/spool/postfix:/sbin/nologin
# chrony:x:998:996::/var/lib/chrony:/sbin/nologin
# sshd:x:74:74:Privilege-separated SSH:/var/empty/sshd:/sbin/nologin
# ntp:x:38:38::/etc/ntp:/sbin/nologin
# tcpdump:x:72:72::/:/sbin/nologin
# nscd:x:28:28:NSCD Daemon:/:/sbin/nologin
# apache:x:48:48:Apache:/usr/share/httpd:/sbin/nologin
# ganglia:x:997:995:Ganglia Monitoring System:/var/lib/ganglia:/sbin/nologin
# hdfs:x:1000:1000::/home/hdfs:/bin/bash
# hadoop:x:1001:1000::/home/hadoop:/bin/bash
# has:x:1002:1000::/home/has:/bin/bash
# oozie:x:1003:1000::/home/oozie:/bin/bash
# mysql:x:27:27:MariaDB Server:/var/lib/mysql:/sbin/nologin
# haproxy:x:188:188:haproxy:/var/lib/haproxy:/sbin/nologin
# apacheds:x:1004:1001::/opt/apacheds-2.0.0-M24:/bin/bash
# hive:x:1005:1000::/home/hive:/bin/bash
# hbase:x:1006:1000::/home/hbase:/bin/bash
# hue:x:1007:1002::/home/hue:/bin/bash
# saslauth:x:996:76:Saslauthd user:/run/saslauthd:/sbin/nologin
# yarn:x:1008:1000::/home/yarn:/bin/bash
# admin:x:1009:1000::/home/admin:/bin/bash
# spark:x:1010:1000::/home/spark:/bin/bash
# knox:x:1011:1000::/home/knox:/bin/bash
# flowagent:x:995:1000::/home/flowagent:/bin/bash
# songyuheng:x:1012:1012::/home/songyuheng:/bin/bash
# wanghansheng:x:1013:1013::/home/wanghansheng:/bin/bash
# zhoujing:x:1014:1014::/home/zhoujing:/bin/bash
# zhangrong:x:1015:1015::/home/zhangrong:/bin/bash
# lifeng:x:1016:1016::/home/lifeng:/bin/bash
# dehua:x:1017:1017::/home/dehua:/bin/bash
# student:x:1018:1018::/home/student:/bin/bash
# tss:x:59:59:Account used by the trousers package to sandbox the tcsd daemon:/dev/null:/sbin/nologin
# nginx:x:994:993:Nginx web server:/var/lib/nginx:/sbin/nologin

# %% [markdown]
# ## File Manipulation

# %%
touch lifeng.txt # create a file

# %%
ls -htla lifeng.txt
# Out:
# -rw-rw-r-- 1 lifeng lifeng 0 Feb 12 23:43 lifeng.txt

# %%
mkdir hello_linux

# %%
ls -htla .
# Out:
# total 56K
# drwxr-xr-x 5 lifeng lifeng 4.0K Feb 12 23:43 .
# drwxrwxr-x 2 lifeng lifeng 4.0K Feb 12 23:43 hello_linux
# -rw-rw-r-- 1 lifeng lifeng    0 Feb 12 23:43 lifeng.txt
# -rw-r--r-- 1 lifeng lifeng 7.3K Feb 12 23:42 L1.2-Linux-Basic.ipynb
# -rw-r--r-- 1 lifeng lifeng  23K Feb 12 23:19 L1.3-Introduction-to-Hadoop.ipynb
# -rw-r--r-- 1 lifeng lifeng 1.8K Feb 12 23:17 L1.1-Introduction-to-Distributed-Computing .ipynb
# drwxr-xr-x 2 lifeng lifeng 4.0K Feb 12 23:16 .ipynb_checkpoints
# drwxr-xr-x 2 lifeng lifeng 4.0K Feb 12 23:02 figures
# drwxr-xr-x 4 lifeng lifeng 4.0K Feb 12 23:00 ..

# %%
cd hello_linux # change directory to hello_linux

# %%
pwd
# Out:
# /home/lifeng/lectures/L1-Introduction/hello_linux

# %%
touch hello.py

# %%
ls
# Out:
# hello.py

# %%
rm hello.py

# %%
cd .. # swtich to parent directory

# %%
pwd
# Out:
# /home/lifeng/lectures

# %%
ls
# Out:
# L1-Introduction  本文件夹下所有文件为只读模式

# %%
cd L1-Introduction

# %%
pwd
# Out:
# /home/lifeng/lectures/L1-Introduction

# %%
mv hello_linux goodbye_linux

# %%
ls
# Out:
# figures
# goodbye_linux
# L1.1-Introduction-to-Distributed-Computing .ipynb
# L1.2-Linux-Basic.ipynb
# L1.3-Introduction-to-Hadoop.ipynb
# lifeng.txt

# %%
rm -rf goodbye_linux

# %%
ls
# Out:
# figures
# L1.1-Introduction-to-Distributed-Computing .ipynb
# L1.2-Linux-Basic.ipynb
# L1.3-Introduction-to-Hadoop.ipynb
# lifeng.txt

# %% [markdown]
# ## Use an editor within a Linux server
#
# - `nano`  : simple to use
# - `vim`   : take a little time to learn
# - `emacs` : steady learning curve

# %% [markdown]
# ## Need help of a command?
#
#
# - We take `mkdir` as an example
#
#     - `man mkdir` shows the standard manual of Linux command
#
#     - `mkdir --help` prints short help for the command

# %% [markdown]
# ## Linux Pipelines
#
#
#
# - cat – Concatenate files
# - sort – Sort lines of text
# - uniq – Report or omit repeated lines
# - grep – Print lines matching a pattern
# - wc – Print newline, word, and byte counts for each file
# - head – Output the first part of a file
# - tail – Output the last part of a file
# - tee – Read from standard input and write to standard output and files

# %% [markdown]
# ## Standard Input, Output, and Error
#
# - Linux theme: "everything is a file."
#
# - The output of a shell program often consists of two types:
#
#     - The program's results, that is, the data the program is designed to produce.
#     - Status and error messages that tell us how the program is getting along.

# %% [markdown]
# - Programs such as `ls` actually send their results to
#
#     - a special file called **standard output** (often expressed as `stdout`) and
#     - their status messages to another file called **standard error** (`stderr`).
#
#     - By default, both standard output and standard error are linked to the screen and not saved into a disk file.
#
# - Many programs take input from a facility called standard input (stdin), which is, by default, attached to the keyboard.

# %% [markdown]
# ## Redirecting Standard Output and Errors

# %%
ls -l /usr/bin > ls-output.txt

# %%
ls -l ls-output.txt
# Out:
# -rw-rw-r-- 1 lifeng lifeng 78060 Feb 26 21:56 ls-output.txt

# %%
cat ls-output.txt
# Out:
# total 393056
# -rwxr-xr-x  1 root root       41488 Aug 20  2019 [
# -rwxr-xr-x  1 root root      107904 Jan 22  2019 a2p
# -rwxr-xr-x  1 root root       52728 Aug  8  2019 ab
# -rwxr-xr-x  1 root root        1661 Nov 21  2015 abs2rel
# -rwxr-xr-x  1 root root       29104 Feb  5 00:35 addr2line
# -rwxr-xr-x  1 root root       39408 Oct 31  2018 afm2tfm
# -rwxr-xr-x  1 root root          29 Aug  8  2019 alias
# lrwxrwxrwx  1 root root          52 Feb 10 18:08 allcm -> /usr/share/texlive/texmf-dist/scripts/tetex/allcm.sh
# lrwxrwxrwx  1 root root           5 Feb 10 18:08 allec -> allcm
# lrwxrwxrwx  1 root root          56 Feb 10 18:08 allneeded -> /usr/share/texlive/texmf-dist/scripts/tetex/allneeded.sh
# lrwxrwxrwx  1 root root          30 Feb 10 18:00 appletviewer -> /etc/alternatives/appletviewer
# lrwxrwxrwx  1 root root           6 Feb 10 17:59 apropos -> whatis
# -rwxr-xr-x  1 root root       62688 Feb  5 00:35 ar
# -rwxr-xr-x  1 root root       33080 Aug 20  2019 arch
# -rwxr-xr-x  1 root root     3980664 Aug  8  2019 aria_chk
# -rwxr-xr-x  1 root root     3768592 Aug  8  2019 aria_dump_log
# -rwxr-xr-x  1 root root     3785336 Aug  8  2019 aria_ftdump
# -rwxr-xr-x  1 root root     3814808 Aug  8  2019 aria_pack
# -rwxr-xr-x  1 root root     3939600 Aug  8  2019 aria_read_log
# -rwxr-xr-x  1 root root      386416 Feb  5 00:35 as
# -rwxr-xr-x  1 root root       28888 Aug  8  2019 aserver
# -rwsr-xr-x  1 root root       53048 Oct 31  2018 at
# lrwxrwxrwx  1 root root           2 Feb 10 17:59 atq -> at
# lrwxrwxrwx  1 root root           2 Feb 10 17:59 atrm -> at
# -rwxr-xr-x  1 root root       14554 Aug  9  2019 audit2allow
# lrwxrwxrwx  1 root root          11 Jan 13 15:22 audit2why -> audit2allow
# -rwxr-xr-x  1 root root       15856 Aug  8  2019 aulast
# -rwxr-xr-x  1 root root       11624 Aug  8  2019 aulastlog
# -rwxr-xr-x  1 root root       11448 Aug  8  2019 ausyscall
# -rwxr-xr-x  1 root root        7706 Jun 24  2015 autoexpect
# -rwxr-xr-x  1 root root       32696 Aug  8  2019 auvirt
# lrwxrwxrwx. 1 root root           4 Oct 15  2017 awk -> gawk
# -rwxr-xr-x  1 root root       37360 Aug 20  2019 base64
# -rwxr-xr-x  1 root root       29032 Aug 20  2019 basename
# -rwxr-xr-x  1 root root      964600 Aug  8  2019 bash
# lrwxrwxrwx  1 root root          10 Feb 10 17:58 bashbug -> bashbug-64
# -rwxr-xr-x  1 root root        6964 Aug  8  2019 bashbug-64
# -rwxr-xr-x  1 root root         137 Oct 31  2018 batch
# -rwxr-xr-x  1 root root       83424 Jun 10  2014 bc
# -rwxr-xr-x  1 root root       45248 Oct 31  2018 bdftopcf
# -rwxr-xr-x  1 root root       11464 Oct 31  2018 bdftruncate
# -rwxr-xr-x  1 root root          26 Aug  8  2019 bg
# -rwxr-xr-x  1 root root      108512 Oct 31  2018 bibtex
# -rwxr-xr-x  1 root root       23289 Mar 18  2017 bond2team
# -rwxr-xr-x  1 root root       70648 Feb  5 00:30 bootctl
# -rwxr-xr-x  1 root root        1537 Nov 21  2015 build-classpath
# -rwxr-xr-x  1 root root         383 Nov 21  2015 build-classpath-directory
# -rwxr-xr-x  1 root root        1571 Nov 21  2015 build-jar-repository
# -rwxr-xr-x  1 root root      408680 Feb  5 00:30 busctl
# -rwxr-xr-x  4 root root      772744 Aug  7  2019 c++
# -rwxr-xr-x  2 root root       36607 Jan 22  2019 c2ph
# -rwxr-xr-x  1 root root         224 Aug  7  2019 c89
# -rwxr-xr-x  1 root root         215 Aug  7  2019 c99
# -rwxr-xr-x  1 root root       71672 Aug  9  2019 cairo-sphinx
# -rwxr-xr-x  1 root root       37688 Dec  3 01:46 cal
# -rwxr-xr-x  1 root root        1638 Nov 27 23:33 ca-legacy
# lrwxrwxrwx  1 root root          30 Feb 10 17:59 cancel -> /etc/alternatives/print-cancel
# -rwxr-xr-x  1 root root       15408 Aug  9  2019 cancel.cups
# lrwxrwxrwx  1 root root           3 Oct 15  2017 captoinfo -> tic
# -rwxr-xr-x  1 root root       54080 Aug 20  2019 cat
# -rwxr-xr-x  1 root root        3336 Aug  7  2019 catchsegv
# -rwxr-xr-x  1 root root       37632 Oct 31  2018 catman
# lrwxrwxrwx  1 root root           3 Feb 10 17:59 cc -> gcc
# -rwxr-xr-x  1 root root          26 Aug  8  2019 cd
# -rwxr-xr-x  1 root root        6280 Feb  5 07:13 centrino-decode
# -rwxr-xr-x  1 root root      175760 Dec 11 04:48 certutil
# -rwxr-xr-x  1 root root       28592 Feb  5 00:35 c++filt
# -rwxr-xr-x  1 root root       15640 Apr 11  2018 chacl
# -rwsr-xr-x  1 root root       73888 Aug  9  2019 chage
# -rwxr-xr-x  1 root root         307 Aug  9  2019 chardetect
# -rwxr-xr-x  1 root root       11616 Aug  9  2019 chattr
# -rwxr-xr-x  1 root root       13430 Aug  9  2019 chcat
# -rwxr-xr-x  1 root root       62936 Aug 20  2019 chcon
# -rwxr-xr-x  1 root root        3328 Nov 21  2015 check-binary-files
# -rwxr-xr-x  1 root root      410096 Oct 31  2018 checkmodule
# -rwxr-xr-x  1 root root      422360 Oct 31  2018 checkpolicy
# -rwxr-xr-x  1 root root        7168 Nov  6  2016 checksctp
# -rwxr-xr-x  1 root root          74 Oct 15  2017 cheetah
# -rwxr-xr-x  1 root root         115 Oct 15  2017 cheetah-analyze
# -rwxr-xr-x  1 root root          90 Oct 15  2017 cheetah-compile
# -rws--x--x  1 root root       23968 Dec  3 01:46 chfn
# -rwxr-xr-x  1 root root       62784 Aug 20  2019 chgrp
# -rwxr-xr-x  1 root root       41400 Dec  3 01:46 chmem
# -rwxr-xr-x  1 root root       58592 Aug 20  2019 chmod
# -rwxr-xr-x  1 root root       62824 Aug 20  2019 chown
# -rwxr-xr-x  1 root root       87072 Aug  8  2019 chronyc
# -rwxr-xr-x  1 root root       32944 Dec  3 01:46 chrt
# -rws--x--x  1 root root       23880 Dec  3 01:46 chsh
# -rwxr-xr-x  1 root root       11480 Oct 31  2018 chvt
# -rwxr-xr-x  1 root root       49672 Aug  9  2019 cifsiostat
# -rwxr-xr-x  1 root root       33152 Aug 20  2019 cksum
# -rwxr-xr-x  1 root root       13220 Nov 21  2015 clean-binary-files
# -rwxr-xr-x  1 root root        7192 Sep  7  2017 clear
# -rwxr-xr-x  1 root root         183 Oct 15  2017 cloud-init
# -rwxr-xr-x  1 root root        1704 Oct 15  2017 cloud-init-per
# -rwxr-xr-x  1 root root          19 Jan  6 13:23 cloud-init-upgrade
# -rwxr-xr-x  1 root root       45272 Aug  9  2019 cmp
# -rwxr-xr-x  1 root root      104912 Dec 11 04:48 cmsutil
# -rwxr-xr-x  1 root root       24448 Dec  3 01:46 col
# -rwxr-xr-x  1 root root       11560 Dec  3 01:46 colcrt
# -rwxr-xr-x  1 root root       24352 Dec  3 01:46 colrm
# -rwxr-xr-x  1 root root       28664 Dec  3 01:46 column
# -rwxr-xr-x  1 root root       37424 Aug 20  2019 comm
# -rwxr-xr-x  1 root root          31 Aug  8  2019 command
# -rwxr-xr-x  1 root root        1480 Aug  9  2019 compile_et
# lrwxrwxrwx  1 root root          71 Feb 10 23:19 configurable-http-proxy -> ../lib/node_modules/configurable-http-proxy/bin/configurable-http-proxy
# -rwxr-xr-x  1 root root      158200 Feb  5 00:30 coredumpctl
# -rwxr-xr-x  1 root root      155176 Aug 20  2019 cp
# -rwxr-xr-x  1 root root      145960 Apr 11  2018 cpio
# -rwxr-xr-x  1 root root      772720 Aug  7  2019 cpp
# -rwxr-xr-x  1 root root       67928 Feb  5 07:13 cpupower
# -rwxr-xr-x  1 root root        4657 Nov 21  2015 create-jar-links
# -rwxr-xr-x  1 root root      121744 Dec 11 04:48 crlutil
# -rwsr-xr-x  1 root root       57656 Aug  9  2019 crontab
# -rwxr-xr-x  1 root root       49992 Aug 20  2019 csplit
# -rwxr-xr-x  1 root root       20096 Oct 31  2018 csslint-0.6
# -rwxr-xr-x  1 root root       15424 Aug  9  2019 cupstestdsc
# -rwxr-xr-x  1 root root       56536 Aug  9  2019 cupstestppd
# -rwxr-xr-x  1 root root      156672 Feb  5 01:00 curl
# -rwxr-xr-x  1 root root       41576 Aug 20  2019 cut
# -rwxr-xr-x  1 root root      247440 Oct 24 23:27 cvtsudoers
# -rwxr-xr-x  1 root root       62200 Aug 20  2019 date
# -rwxr-xr-x  1 root root       11496 Aug  9  2019 db_archive
# -rwxr-xr-x  1 root root       11576 Aug  9  2019 db_checkpoint
# -rwxr-xr-x  1 root root       11584 Aug  9  2019 db_deadlock
# -rwxr-xr-x  1 root root       15696 Aug  9  2019 db_dump
# -rwxr-xr-x  1 root root       65992 Aug  9  2019 db_dump185
# -rwxr-xr-x  1 root root       15712 Aug  9  2019 db_hotbackup
# -rwxr-xr-x  1 root root        1465 Jun 10  2014 dbilogstrip
# -rwxr-xr-x  1 root root        6293 Jun 10  2014 dbiprof
# -rwxr-xr-x  1 root root        5474 Jun 10  2014 dbiproxy
# -rwxr-xr-x  1 root root       28168 Aug  9  2019 db_load
# -rwxr-xr-x  1 root root       15704 Aug  9  2019 db_log_verify
# -rwxr-xr-x  1 root root       33032 Aug  9  2019 db_printlog
# -rwxr-xr-x  1 root root       11600 Aug  9  2019 db_recover
# -rwxr-xr-x  1 root root       15712 Aug  9  2019 db_replicate
# -rwxr-xr-x  1 root root       15624 Aug  9  2019 db_stat
# -rwxr-xr-x  1 root root       19792 Aug  9  2019 db_tuner
# -rwxr-xr-x  1 root root       11504 Aug  9  2019 db_upgrade
# -rwxr-xr-x. 1 root root       96760 Jun 10  2014 dbus-binding-tool
# -rwxr-xr-x  1 root root       11344 Mar 14  2019 dbus-cleanup-sockets
# -rwxr-xr-x  1 root root      223320 Mar 14  2019 dbus-daemon
# -rwxr-xr-x  1 root root       23760 Mar 14  2019 dbus-monitor
# -rwxr-xr-x  1 root root       15408 Mar 14  2019 dbus-run-session
# -rwxr-xr-x  1 root root       27800 Mar 14  2019 dbus-send
# -rwxr-xr-x  1 root root       23768 Mar 14  2019 dbus-test-tool
# -rwxr-xr-x  1 root root       15480 Mar 14  2019 dbus-update-activation-environment
# -rwxr-xr-x  1 root root       11328 Mar 14  2019 dbus-uuidgen
# -rwxr-xr-x  1 root root       11520 Aug  9  2019 db_verify
# -rwxr-xr-x  1 root root       45392 Jun 10  2014 dc
# -rwxr-xr-x  1 root root       74896 Aug 20  2019 dd
# -rwxr-xr-x  1 root root       11496 Oct 31  2018 deallocvt
# -rwxr-xr-x  1 root root        8071 Aug  9  2019 debuginfo-install
# lrwxrwxrwx  1 root root          20 Feb 10 18:08 desktop-file-edit -> desktop-file-install
# -rwxr-xr-x  1 root root       76520 Aug  9  2019 desktop-file-install
# -rwxr-xr-x  1 root root       64184 Aug  9  2019 desktop-file-validate
# -rwxr-xr-x  1 root root      105016 Aug 20  2019 df
# -rwxr-xr-x. 1 root root      514168 Jun 29  2017 dgawk
# -rwxr-xr-x  1 root root      200224 Aug  9  2019 diff
# -rwxr-xr-x  1 root root       62200 Aug  9  2019 diff3
# -rwxr-xr-x  1 root root        1236 Nov 21  2015 diff-jars
# -rwxr-xr-x  1 root root      117608 Aug 20  2019 dir
# -rwxr-xr-x  1 root root         225 Jan 28  2018 dir2pi
# -rwxr-xr-x  1 root root       41408 Aug 20  2019 dircolors
# -rwxr-xr-x  1 root root       28992 Aug 20  2019 dirname
# -rwxr-xr-x  1 root root        7938 Jun 24  2015 dislocate
# -rwxr-xr-x  1 root root       49680 Dec  3 01:46 dmesg
# lrwxrwxrwx  1 root root           8 Feb 10 17:59 dnsdomainname -> hostname
# -rwxr-xr-x  1 root root    33061032 Jul 19  2018 docker
# -rwxr-xr-x  1 root root    38076568 Jul 19  2018 docker-containerd
# -rwxr-xr-x  1 root root    20895160 Jul 19  2018 docker-containerd-ctr
# -rwxr-xr-x  1 root root     4173632 Jul 19  2018 docker-containerd-shim
# -rwxr-xr-x  1 root root    68465264 Jul 19  2018 dockerd
# -rwxr-xr-x  1 root root      849224 Jul 19  2018 docker-init
# -rwxr-xr-x  1 root root     2411096 Jul 19  2018 docker-proxy
# -rwxr-xr-x  1 root root     7639448 Jul 19  2018 docker-runc
# lrwxrwxrwx  1 root root           8 Feb 10 17:59 domainname -> hostname
# -rwxr-xr-x  1 root root       57002 Aug  9  2019 dracut
# -rwxr-xr-x  1 root root        8638 Dec 25  2015 dshbak
# -rwxr-xr-x  1 root root      112992 Aug 20  2019 du
# -rwxr-xr-x  1 root root       79440 Oct 31  2018 dumpkeys
# lrwxrwxrwx  1 root root          54 Feb 10 18:08 dvi2fax -> /usr/share/texlive/texmf-dist/scripts/tetex/dvi2fax.sh
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 dvilualatex -> luatex
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 dviluatex -> luatex
# -rwxr-xr-x  1 root root        1026 Dec  3 01:54 dvipdf
# lrwxrwxrwx  1 root root           8 Feb 10 18:07 dvipdfm -> dvipdfmx
# -rwxr-xr-x  1 root root      617592 Oct 31  2018 dvipdfmx
# -rwxr-xr-x  1 root root        2688 Oct 31  2018 dvipdft
# -rwxr-xr-x  1 root root      204944 Oct 31  2018 dvips
# lrwxrwxrwx  1 root root          53 Feb 10 18:08 dvired -> /usr/share/texlive/texmf-dist/scripts/tetex/dvired.sh
# -rwxr-xr-x  1 root root     3178136 Feb  5 00:35 dwp
# -rwxr-xr-x  1 root root      166504 Jun 10  2014 dwz
# -rwxr-xr-x  1 root root         234 Oct 15  2017 easy_install
# -rwxr-xr-x  1 root root         234 Oct 15  2017 easy_install-2.7
# lrwxrwxrwx  1 root root           8 Feb 10 18:07 ebb -> dvipdfmx
# -rwxr-xr-x  1 root root       33088 Aug 20  2019 echo
# lrwxrwxrwx  1 root root          40 Feb 20 10:45 ecm-python-wrap -> /var/lib/ecm-agent/lib/python/bin/python
# -rwxr-xr-x  1 root root       49848 Jun 10  2014 ed
# -rwxr-xr-x. 1 root root         290 Aug  3  2017 egrep
# -rwxr-xr-x  1 root root       49984 Dec  3 01:46 eject
# -rwxr-xr-x  1 root root       32952 Feb  5 00:35 elfedit
# lrwxrwxrwx  1 root root          38 Jul 10  2018 emr-agent -> /usr/local/emr/emr-agent/bin/emr-agent
# lrwxrwxrwx  1 root root          44 Nov  2  2017 emr-watchdog -> /usr/local/emr/emr-watchdog/bin/emr-watchdog
# -rwxr-xr-x  1 root root       29008 Aug 20  2019 env
# -rwxr-xr-x. 1 root root       36872 Aug  3  2017 envsubst
# -rwxr-xr-x  1 root root         639 Dec  3 01:54 eps2eps
# -rwxr-xr-x. 1 root root      147880 Jun 10  2014 eqn
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 etex -> pdftex
# lrwxrwxrwx  1 root root           2 Feb 10 17:59 ex -> vi
# -rwxr-xr-x  1 root root       33264 Aug 20  2019 expand
# -rwxr-xr-x  1 root root       11352 Jun 24  2015 expect
# -rwxr-xr-x  1 root root       37408 Aug 20  2019 expr
# lrwxrwxrwx  1 root root          26 Feb 10 18:00 extcheck -> /etc/alternatives/extcheck
# lrwxrwxrwx  1 root root           8 Feb 10 18:07 extractbb -> dvipdfmx
# lrwxrwxrwx  1 root root           8 Feb 10 18:07 f95 -> gfortran
# -rwxr-xr-x  1 root root       95528 Aug 20  2019 factor
# -rwxr-xr-x  1 root root       28512 Dec  3 01:46 fallocate
# -rwxr-xr-x  1 root root       28928 Aug 20  2019 false
# -rwxr-xr-x  1 root root          26 Aug  8  2019 fc
# -rwxr-xr-x  1 root root         132 Oct 30  2018 fc-cache
# -rwxr-xr-x  1 root root       15824 Oct 31  2018 fc-cache-64
# -rwxr-xr-x  1 root root       15768 Oct 31  2018 fc-cat
# -rwxr-xr-x  1 root root       11464 Oct 31  2018 fc-conflist
# -rwxr-xr-x  1 root root       11528 Oct 31  2018 fc-list
# -rwxr-xr-x  1 root root       11592 Oct 31  2018 fc-match
# -rwxr-xr-x  1 root root       11528 Oct 31  2018 fc-pattern
# -rwxr-xr-x  1 root root       11496 Oct 31  2018 fc-query
# -rwxr-xr-x  1 root root       11536 Oct 31  2018 fc-scan
# -rwxr-xr-x  1 root root       11536 Oct 31  2018 fc-validate
# -rwxr-xr-x  1 root root          26 Aug  8  2019 fg
# -rwxr-xr-x  1 root root       11504 Oct 31  2018 fgconsole
# -rwxr-xr-x. 1 root root         290 Aug  3  2017 fgrep
# -rwxr-xr-x  1 root root       19848 Oct 31  2018 file
# -rwxr-xr-x  1 root root      199304 Oct 31  2018 find
# -rwxr-xr-x  1 root root       23614 Jan 22  2019 find2perl
# -rwxr-xr-x  1 root root         748 Nov 21  2015 find-jar
# -rwxr-xr-x  1 root root       59768 Dec  3 01:46 findmnt
# -rwxr-xr-x  1 root root        4371 Aug  9  2019 find-repos-of-install
# -rwxr-xr-x. 1 root root       15736 Aug  2  2017 fipscheck
# -rwxr-xr-x. 1 root root       11576 Aug  2  2017 fipshmac
# -rwxr-xr-x  1 root root      116196 Feb  5 00:29 firewall-cmd
# -rwxr-xr-x  1 root root      103607 Feb  5 00:29 firewall-offline-cmd
# -rwxr-xr-x  1 root root         212 Apr 23  2018 flask
# -rwxr-xr-x  1 root root       24448 Dec  3 01:46 flock
# -rwxr-xr-x  1 root root       37360 Aug 20  2019 fmt
# lrwxrwxrwx  1 root root          49 Feb 10 18:08 fmtutil -> /usr/share/texlive/texmf/scripts/tetex/fmtutil.sh
# lrwxrwxrwx  1 root root          53 Feb 10 18:08 fmtutil-sys -> /usr/share/texlive/texmf/scripts/tetex/fmtutil-sys.sh
# -rwxr-xr-x  1 root root       37336 Aug 20  2019 fold
# -rwxr-xr-x  1 root root       36856 Oct 31  2018 fonttosfnt
# -rwxr-xr-x  1 root root       19792 Oct 19 00:08 free
# -rwxr-xr-x  1 root root        4491 Aug  9  2019 freetype-config
# -rwxr-xr-x  1 root root       16480 Dec 23 23:39 fribidi
# -rwxr-xr-x  1 root root         683 Jun 24  2015 ftp-rfc
# -rwxr-xr-x  1 root root       32136 Aug  9  2019 funzip
# -rwsr-xr-x  1 root root       32096 Oct 31  2018 fusermount
# -rwxr-xr-x  4 root root      772744 Aug  7  2019 g++
# -rwxr-xr-x  1 root root       19944 Aug  9  2019 gapplication
# -rwxr-xr-x. 1 root root      428584 Jun 29  2017 gawk
# -rwxr-xr-x  2 root root      768648 Aug  7  2019 gcc
# -rwxr-xr-x  1 root root       27136 Aug  7  2019 gcc-ar
# -rwxr-xr-x  1 root root       27136 Aug  7  2019 gcc-nm
# -rwxr-xr-x  1 root root       27144 Aug  7  2019 gcc-ranlib
# -rwxr-xr-x  1 root root      314904 Aug  7  2019 gcov
# -rwxr-xr-x  1 root root       41136 Aug  9  2019 gdbus
# -rwxr-xr-x  1 root root       15752 Oct 31  2018 gdk-pixbuf-query-loaders-64
# -rwxr-xr-x  1 root root       15968 Oct 31  2018 gdk-pixbuf-thumbnailer
# -rwxr-xr-x  1 root root       23136 Aug  7  2019 gencat
# -rwxr-xr-x. 2 root root       11544 Aug  4  2017 genl-ctrl-list
# -rwxr-xr-x  1 root root       15648 Aug  9  2019 geoiplookup
# -rwxr-xr-x  1 root root       11424 Aug  9  2019 geoiplookup6
# -rwxr-xr-x  1 root root       32072 Aug 13  2019 geoipupdate
# lrwxrwxrwx. 1 root root           3 Oct 15  2017 geqn -> eqn
# -rwxr-xr-x  1 root root       22920 Aug  7  2019 getconf
# -rwxr-xr-x  1 root root       27896 Aug  7  2019 getent
# -rwxr-xr-x  1 root root       24872 Apr 11  2018 getfacl
# -rwxr-xr-x  1 root root       11496 Oct 31  2018 getkeycodes
# -rwxr-xr-x  1 root root       15752 Dec  3 01:46 getopt
# -rwxr-xr-x  1 root root          31 Aug  8  2019 getopts
# -rwxr-xr-x. 1 root root       36800 Aug  3  2017 gettext
# -rwxr-xr-x. 1 root root        4629 Aug  3  2017 gettext.sh
# -rwxr-xr-x  1 root root      772728 Aug  7  2019 gfortran
# -rwxr-xr-x  1 root root       45088 Oct 31  2018 gftodvi
# -rwxr-xr-x  1 root root       28368 Oct 31  2018 gftopk
# -rwxr-xr-x  1 root root       28296 Oct 31  2018 gftype
# lrwxrwxrwx  1 root root          11 Feb 10 18:08 ghostscript -> /usr/bin/gs
# -rwxr-xr-x  1 root root       75176 Aug  9  2019 gio
# -rwxr-xr-x  1 root root       11592 Aug  9  2019 gio-querymodules-64
# -rwxr-xr-x  3 root root     2242320 Dec 26 03:53 git
# -rwxr-xr-x  3 root root     2242320 Dec 26 03:53 git-receive-pack
# -rwxr-xr-x  1 root root     1189752 Dec 26 03:53 git-shell
# -rwxr-xr-x  3 root root     2242320 Dec 26 03:53 git-upload-archive
# -rwxr-xr-x  1 root root     1278136 Dec 26 03:53 git-upload-pack
# -rwxr-xr-x  1 root root       45440 Aug  9  2019 glib-compile-schemas
# lrwxrwxrwx  1 root root           4 Feb 10 17:59 gmake -> make
# -rwxr-xr-x  1 root root       20672 Oct 13  2015 gmetric
# lrwxrwxrwx. 1 root root           4 Oct 15  2017 gneqn -> neqn
# lrwxrwxrwx. 1 root root           5 Oct 15  2017 gnroff -> nroff
# -rwsr-xr-x  1 root root       78408 Aug  9  2019 gpasswd
# lrwxrwxrwx  1 root root           4 Jan 14 10:54 gpg -> gpg2
# -rwxr-xr-x  1 root root      749976 Jul 13  2018 gpg2
# -rwxr-xr-x  1 root root      296696 Jul 13  2018 gpg-agent
# -rwxr-xr-x  1 root root      143680 Jul 13  2018 gpgconf
# -rwxr-xr-x  1 root root      156352 Jul 13  2018 gpg-connect-agent
# -rwxr-xr-x. 1 root root       23736 Jun 10  2014 gpg-error
# -rwxr-xr-x  1 root root       24272 Jul 13  2018 gpgparsemail
# -rwxr-xr-x  1 root root       50056 Jul 13  2018 gpgsplit
# lrwxrwxrwx  1 root root           5 Jan 14 10:54 gpgv -> gpgv2
# -rwxr-xr-x  1 root root      353672 Jul 13  2018 gpgv2
# -rwxr-xr-x  1 root root        3307 Jul 13  2018 gpg-zip
# lrwxrwxrwx. 1 root root           3 Oct 15  2017 gpic -> pic
# -rwxr-xr-x  1 root root      100776 Feb  5 00:35 gprof
# -rwxr-xr-x  1 root root       24224 Jul 21  2017 gr2fonttest
# -rwxr-xr-x. 1 root root      159024 Aug  3  2017 grep
# -rwxr-xr-x. 1 root root       83584 Jun 10  2014 groff
# -rwxr-xr-x. 1 root root      144232 Jun 10  2014 grops
# -rwxr-xr-x. 1 root root      100952 Jun 10  2014 grotty
# -rwxr-xr-x  1 root root       33192 Aug 20  2019 groups
# -rwxr-xr-x  1 root root       22513 Jan  6 13:23 growpart
# -rwxr-xr-x  1 root root      401448 Aug  8  2019 grub2-editenv
# -rwxr-xr-x  1 root root      833888 Aug  8  2019 grub2-file
# -rwxr-xr-x  1 root root     1062640 Aug  8  2019 grub2-fstest
# -rwxr-xr-x  1 root root      260920 Aug  8  2019 grub2-glue-efi
# -rwxr-xr-x  1 root root        1668 Aug  8  2019 grub2-kbdcomp
# -rwxr-xr-x  1 root root      243520 Aug  8  2019 grub2-menulst2cfg
# -rwxr-xr-x  1 root root      290400 Aug  8  2019 grub2-mkfont
# -rwxr-xr-x  1 root root      384136 Aug  8  2019 grub2-mkimage
# -rwxr-xr-x  1 root root      267120 Aug  8  2019 grub2-mklayout
# -rwxr-xr-x  1 root root      435960 Aug  8  2019 grub2-mknetdir
# -rwxr-xr-x  1 root root      273720 Aug  8  2019 grub2-mkpasswd-pbkdf2
# -rwxr-xr-x  1 root root      260568 Aug  8  2019 grub2-mkrelpath
# -rwxr-xr-x  1 root root     1025760 Aug  8  2019 grub2-mkrescue
# -rwxr-xr-x  1 root root      538880 Aug  8  2019 grub2-mkstandalone
# -rwxr-xr-x  1 root root      842904 Aug  8  2019 grub2-render-label
# -rwxr-xr-x  1 root root      298368 Aug  8  2019 grub2-script-check
# -rwxr-xr-x  1 root root      769672 Aug  8  2019 grub2-syslinux2cfg
# -rwxr-xr-x  1 root root       11232 Dec  3 01:54 gs
# -rwxr-xr-x  1 root root         350 Dec  3 01:54 gsbj
# -rwxr-xr-x  1 root root         352 Dec  3 01:54 gsdj
# -rwxr-xr-x  1 root root         352 Dec  3 01:54 gsdj500
# -rwxr-xr-x  1 root root       24376 Aug  9  2019 gsettings
# -rwxr-xr-x  1 root root       28632 Oct 31  2018 gsftopk
# -rwxr-xr-x  1 root root         353 Dec  3 01:54 gslj
# -rwxr-xr-x  1 root root         350 Dec  3 01:54 gslp
# -rwxr-xr-x  1 root root         277 Dec  3 01:54 gsnd
# lrwxrwxrwx. 1 root root           6 Oct 15  2017 gsoelim -> soelim
# -rwxr-xr-x  1 root root       23728 Sep 14 02:05 gss-client
# -rwxr-xr-x  1 root root       20360 Oct 13  2015 gstat
# lrwxrwxrwx  1 root root           3 Feb 10 17:59 gtar -> tar
# lrwxrwxrwx. 1 root root           3 Oct 15  2017 gtbl -> tbl
# -rwxr-xr-x  1 root root       15656 Aug  2  2017 gtk-query-immodules-2.0-64
# -rwxr-xr-x  1 root root       33296 Oct 31  2018 gtk-update-icon-cache
# lrwxrwxrwx. 1 root root           5 Oct 15  2017 gtroff -> troff
# -rwxr-xr-x  1 root root        2253 Apr 11  2018 gunzip
# -rwxr-xr-x  1 root root        5931 Apr 11  2018 gzexe
# -rwxr-xr-x  1 root root      100800 Apr 11  2018 gzip
# -rwxr-xr-x  1 root root       28310 Jan 22  2019 h2ph
# -rwxr-xr-x  1 root root       36728 Aug  9  2019 halog
# -rwxr-xr-x. 1 root root       11448 Nov  6  2016 hdsploader
# -rwxr-xr-x  1 root root       41472 Aug 20  2019 head
# -rwxr-xr-x  1 root root       32784 Dec  3 01:46 hexdump
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 hostid
# -rwxr-xr-x  1 root root       15784 Oct 19 00:02 hostname
# -rwxr-xr-x  1 root root      325712 Feb  5 00:30 hostnamectl
# -rwxr-xr-x  1 root root       23736 Aug  8  2019 htdbm
# -rwxr-xr-x  1 root root       15520 Aug  8  2019 htdigest
# -rwxr-xr-x  1 root root      169624 Jan 17  2019 htop
# -rwxr-xr-x  1 root root       19640 Aug  8  2019 htpasswd
# -rwxr-xr-x  1 root root       11336 Aug  8  2019 httxt2dbm
# lrwxrwxrwx  1 root root           7 Feb 10 17:59 i386 -> setarch
# -rwxr-xr-x  1 root root       32496 Aug 12  2017 iceauth
# -rwxr-xr-x  1 root root       60376 Aug  7  2019 iconv
# -rwxr-xr-x  1 root root         172 Aug  6  2019 icu-config
# -rwxr-xr-x  1 root root       22004 Aug  9  2019 icu-config-64
# -rwxr-xr-x  1 root root       15976 Aug  9  2019 icuinfo
# -rwxr-xr-x  1 root root       37400 Aug 20  2019 id
# -rwxr-xr-x. 1 root root       11608 Aug  4  2017 idiag-socket-details
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 idlj -> /etc/alternatives/idlj
# -rwxr-xr-x. 1 root root       33232 Nov 22  2015 idn
# -rwxr-xr-x. 1 root root        3188 Jun 29  2017 igawk
# -rwxr-xr-x  1 root root      271552 Apr 11  2018 info
# -rwxr-xr-x  1 root root       57416 Sep  7  2017 infocmp
# -rwxr-xr-x  1 root root       21984 Apr 11  2018 infokey
# lrwxrwxrwx  1 root root           3 Oct 15  2017 infotocap -> tic
# lrwxrwxrwx  1 root root           2 Feb 10 18:08 inimf -> mf
# lrwxrwxrwx  1 root root           3 Feb 10 18:08 initex -> tex
# -rwxr-xr-x  1 root root       11384 Aug  8  2019 innochecksum
# -rwxr-xr-x  1 root root      142944 Aug 20  2019 install
# -rwxr-xr-x  1 root root       24432 Dec  3 01:46 ionice
# -rwxr-xr-x  1 root root       62232 Aug  9  2019 iostat
# -rwxr-xr-x  1 root root       15416 Aug  9  2019 ipcalc
# -rwxr-xr-x  1 root root       24584 Dec  3 01:46 ipcmk
# -rwxr-xr-x  1 root root       28520 Dec  3 01:46 ipcrm
# -rwxr-xr-x  1 root root       49520 Dec  3 01:46 ipcs
# -rwxr-xr-x  1 root root       10384 Aug  9  2019 iprange
# lrwxrwxrwx  1 root root          23 Feb 10 17:58 iptables-xml -> /usr/sbin/xtables-multi
# -rwxr-xr-x  1 root root       24400 Dec  3 01:46 isosize
# lrwxrwxrwx  1 root root          21 Feb 10 18:00 jar -> /etc/alternatives/jar
# lrwxrwxrwx  1 root root          27 Feb 10 18:00 jarsigner -> /etc/alternatives/jarsigner
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 java -> /etc/alternatives/java
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 javac -> /etc/alternatives/javac
# lrwxrwxrwx  1 root root          25 Feb 10 18:00 javadoc -> /etc/alternatives/javadoc
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 javah -> /etc/alternatives/javah
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 javap -> /etc/alternatives/javap
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 jcmd -> /etc/alternatives/jcmd
# lrwxrwxrwx  1 root root          26 Feb 10 18:00 jconsole -> /etc/alternatives/jconsole
# lrwxrwxrwx  1 root root          21 Feb 10 18:00 jdb -> /etc/alternatives/jdb
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 jdeps -> /etc/alternatives/jdeps
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 jhat -> /etc/alternatives/jhat
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 jinfo -> /etc/alternatives/jinfo
# lrwxrwxrwx  1 root root          21 Feb 10 18:00 jjs -> /etc/alternatives/jjs
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 jmap -> /etc/alternatives/jmap
# -rwxr-xr-x  1 root root          28 Aug  8  2019 jobs
# -rwxr-xr-x  1 root root       49920 Aug 20  2019 join
# -rwxr-xr-x  1 root root      550752 Feb  5 00:30 journalctl
# lrwxrwxrwx  1 root root          21 Feb 10 18:00 jps -> /etc/alternatives/jps
# lrwxrwxrwx  1 root root          28 Feb 10 18:00 jrunscript -> /etc/alternatives/jrunscript
# lrwxrwxrwx  1 root root          27 Feb 10 18:00 jsadebugd -> /etc/alternatives/jsadebugd
# -rwxr-xr-x  1 root root        1018 Oct 15  2017 jsondiff
# -rwxr-xr-x  1 root root        3661 Oct 15  2017 jsonpatch
# -rwxr-xr-x  1 root root        1341 Oct 15  2017 jsonpointer
# lrwxrwxrwx  1 root root          24 Feb 10 18:00 jstack -> /etc/alternatives/jstack
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 jstat -> /etc/alternatives/jstat
# lrwxrwxrwx  1 root root          24 Feb 10 18:00 jstatd -> /etc/alternatives/jstatd
# -rwxr-xr-x  1 root root        1737 Nov 21  2015 jvmjar
# -rwxr-xr-x  1 root root        2004 Sep 14 02:05 k5srvutil
# -rwxr-xr-x  1 root root       77464 Sep 14 02:05 kadmin
# -rwxr-xr-x  1 root root       11528 Oct 31  2018 kbdinfo
# -rwxr-xr-x  1 root root       11504 Oct 31  2018 kbd_mode
# -rwxr-xr-x  1 root root       11560 Oct 31  2018 kbdrate
# -rwxr-xr-x  1 root root       11232 Sep 14 02:05 kdestroy
# -rwxr-xr-x  1 root root       32623 Aug  8  2019 kdumpctl
# -rwxr-xr-x  1 root root        4811 Feb  5 00:29 kernel-install
# lrwxrwxrwx  1 root root          25 Feb 10 18:00 keytool -> /etc/alternatives/keytool
# -rwxr-xr-x  1 root root       10886 Jun 24  2015 kibitz
# -rwxr-xr-x  1 root root       33608 Dec  3 01:46 kill
# -rwxr-xr-x  1 root root       24720 Aug  9  2019 killall
# -rwxr-xr-x  1 root root       27672 Sep 14 02:05 kinit
# -rwxr-xr-x  1 root root       27832 Sep 14 02:05 klist
# -rwxr-xr-x  1 root root      146688 Aug  9  2019 kmod
# -rwxr-xr-x  1 root root       11216 Sep 14 02:05 kpasswd
# -rwxr-xr-x  1 root root        7264 Oct 31  2018 kpseaccess
# lrwxrwxrwx  1 root root           8 Feb 10 18:08 kpsepath -> kpsetool
# -rwxr-xr-x  1 root root        7272 Oct 31  2018 kpsereadlink
# -rwxr-xr-x  1 root root       11376 Oct 31  2018 kpsestat
# lrwxrwxrwx  1 root root          55 Feb 10 18:08 kpsetool -> /usr/share/texlive/texmf-dist/scripts/tetex/kpsetool.sh
# lrwxrwxrwx  1 root root          56 Feb 10 18:08 kpsewhere -> /usr/share/texlive/texmf-dist/scripts/tetex/kpsewhere.sh
# -rwxr-xr-x  1 root root       20744 Oct 31  2018 kpsewhich
# lrwxrwxrwx  1 root root           8 Feb 10 18:08 kpsexpand -> kpsetool
# -rwxr-xr-x  1 root root        7123 Sep 14 02:05 krb5-config
# -rwsr-xr-x  1 root root       61320 Sep 14 02:05 ksu
# -rwxr-xr-x  1 root root       11224 Sep 14 02:05 kswitch
# -rwxr-xr-x  1 root root       23688 Sep 14 02:05 ktutil
# -rwxr-xr-x  1 root root       15360 Sep 14 02:05 kvno
# -rwxr-xr-x. 1 root root       19568 Jun 10  2014 last
# lrwxrwxrwx. 1 root root           4 Oct 15  2017 lastb -> last
# -rwxr-xr-x  1 root root       19608 Aug  9  2019 lastlog
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 latex -> pdftex
# -rwxr-xr-x  1 root root       15896 Apr 13  2018 lchfn
# -rwxr-xr-x  1 root root       15864 Apr 13  2018 lchsh
# lrwxrwxrwx  1 root root          20 Feb 10 17:58 ld -> /etc/alternatives/ld
# lrwxrwxrwx  1 root root          10 Feb 10 17:59 ldapadd -> ldapmodify
# -rwxr-xr-x  1 root root       61256 Jan 30  2019 ldapcompare
# -rwxr-xr-x  1 root root       65416 Jan 30  2019 ldapdelete
# -rwxr-xr-x  1 root root       61248 Jan 30  2019 ldapexop
# -rwxr-xr-x  1 root root       73576 Jan 30  2019 ldapmodify
# -rwxr-xr-x  1 root root       61264 Jan 30  2019 ldapmodrdn
# -rwxr-xr-x  1 root root       65344 Jan 30  2019 ldappasswd
# -rwxr-xr-x  1 root root       85928 Jan 30  2019 ldapsearch
# -rwxr-xr-x  1 root root       19728 Jan 30  2019 ldapurl
# -rwxr-xr-x  1 root root       61264 Jan 30  2019 ldapwhoami
# -rwxr-xr-x  1 root root     1006216 Feb  5 00:35 ld.bfd
# -rwxr-xr-x  1 root root        5302 Aug  7  2019 ldd
# -rwxr-xr-x  1 root root     5354120 Feb  5 00:35 ld.gold
# -rwxr-xr-x. 1 root root      158240 Jul 31  2015 less
# -rwxr-xr-x. 1 root root       11376 Jul 31  2015 lessecho
# -rwxr-xr-x. 1 root root       17056 Jul 31  2015 lesskey
# -rwxr-xr-x. 1 root root        2291 Jul 31  2015 lesspipe.sh
# -rwxr-xr-x  1 root root       87128 Oct 31  2018 lexgrog
# -rwxr-xr-x  1 root root        2437 Dec 10  2015 libpng15-config
# lrwxrwxrwx  1 root root          15 Feb 10 18:08 libpng-config -> libpng15-config
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 link
# lrwxrwxrwx  1 root root           7 Feb 10 17:59 linux32 -> setarch
# lrwxrwxrwx  1 root root           7 Feb 10 17:59 linux64 -> setarch
# -rwxr-xr-x. 1 root root        5995 Nov  6  2016 linux-boot-prober
# -rwxr-xr-x  1 root root       58592 Aug 20  2019 ln
# -rwxr-xr-x  1 root root      113184 Oct 31  2018 loadkeys
# -rwxr-xr-x  1 root root       24544 Oct 31  2018 loadunimap
# -rwxr-xr-x  1 root root       38720 Aug  7  2019 locale
# -rwxr-xr-x  1 root root      334016 Feb  5 00:30 localectl
# -rwxr-xr-x  1 root root      322928 Aug  7  2019 localedef
# -rwx--s--x  1 root slocate    40520 Apr 11  2018 locate
# -rwxr-xr-x  1 root root       29312 Dec  3 01:46 logger
# -rwxr-xr-x  1 root root       37248 Dec  3 01:46 login
# -rwxr-xr-x  1 root root      501344 Feb  5 00:30 loginctl
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 logname
# -rwxr-xr-x  1 root root       11344 Aug  8  2019 logresolve
# -rwxr-xr-x  1 root root       11544 Dec  3 01:46 look
# lrwxrwxrwx  1 root root          26 Feb 10 17:59 lp -> /etc/alternatives/print-lp
# -rwxr-xr-x  1 root root       19528 Aug  9  2019 lp.cups
# -rwxr-xr-x  1 root root       15440 Aug  9  2019 lpoptions
# -rwxr-xr-x  1 root root       15416 Aug  9  2019 lppasswd
# lrwxrwxrwx  1 root root          27 Feb 10 17:59 lpq -> /etc/alternatives/print-lpq
# -rwxr-xr-x  1 root root       19568 Aug  9  2019 lpq.cups
# lrwxrwxrwx  1 root root          23 Feb 10 17:59 lpr -> /etc/alternatives/print
# -rwxr-xr-x  1 root root       15400 Aug  9  2019 lpr.cups
# lrwxrwxrwx  1 root root          28 Feb 10 17:59 lprm -> /etc/alternatives/print-lprm
# -rwxr-xr-x  1 root root       11296 Aug  9  2019 lprm.cups
# -rwxr-xr-x  1 root root        5470 Dec  3 01:54 lprsetup.sh
# lrwxrwxrwx  1 root root          30 Feb 10 17:59 lpstat -> /etc/alternatives/print-lpstat
# -rwxr-xr-x  1 root root       32232 Aug  9  2019 lpstat.cups
# -rwxr-xr-x  1 root root        2619 Jun 24  2015 lpunlock
# -rwxr-xr-x  1 root root      117608 Aug 20  2019 ls
# -rwxr-xr-x  1 root root     2356616 Jun 10  2016 lsar
# -rwxr-xr-x  1 root root       11600 Aug  9  2019 lsattr
# -rwxr-xr-x  1 root root       81072 Dec  3 01:46 lsblk
# -rwxr-xr-x  1 root root       15929 Mar 27  2015 lsb_release
# -rwxr-xr-x  1 root root       62208 Dec  3 01:46 lscpu
# -rwxr-xr-x  1 root root        6410 Aug  9  2019 lsinitrd
# -rwxr-xr-x  1 root root       62408 Dec  3 01:46 lsipc
# -rwxr-xr-x  1 root root       42000 Dec  3 01:46 lslocks
# -rwxr-xr-x  1 root root       54152 Dec  3 01:46 lslogins
# -rwxr-xr-x  1 root root       41760 Dec  3 01:46 lsmem
# -rwxr-xr-x  1 root root       37304 Dec  3 01:46 lsns
# -rwxr-xr-x. 1 root root       57832 Aug  3  2017 lsscsi
# -rwxr-xr-x. 1 root root       15840 Nov  6  2016 lua
# -rwxr-xr-x. 1 root root      121888 Nov  6  2016 luac
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 lualatex -> luatex
# -rwxr-xr-x  1 root root     6079960 Oct 31  2018 luatex
# -rwxr-xr-x  1 root root      124344 Aug  9  2019 lz4
# -rwxr-xr-x  1 root root      124344 Aug  9  2019 lz4c
# lrwxrwxrwx  1 root root           3 Jan 14 09:55 lz4cat -> lz4
# -rwxr-xr-x  1 root root      154800 Nov 20  2015 m4
# -rwxr-xr-x  1 root root      546704 Feb  5 00:30 machinectl
# lrwxrwxrwx  1 root root           5 Feb 10 18:00 mail -> mailx
# lrwxrwxrwx  1 root root          15 Feb 10 18:00 Mail -> ../../bin/mailx
# lrwxrwxrwx  1 root root          27 Feb 10 17:59 mailq -> /etc/alternatives/mta-mailq
# lrwxrwxrwx  1 root root          31 Feb 10 17:59 mailq.postfix -> ../../usr/sbin/sendmail.postfix
# -rwxr-xr-x  1 root root      392880 Apr 11  2018 mailx
# -rwxr-xr-x  1 root root      182752 Aug  9  2019 make
# -rwxr-xr-x  1 root root       19072 Aug  7  2019 makedb
# -rwxr-xr-x  1 root root       79912 Oct 31  2018 makeindex
# lrwxrwxrwx  1 root root           8 Feb 10 18:08 makeinfo -> texi2any
# -rwxr-xr-x  1 root root      102848 Oct 31  2018 man
# -rwxr-xr-x  1 root root      125184 Oct 31  2018 mandb
# -rwxr-xr-x  1 root root       33336 Oct 31  2018 manpath
# -rwxr-xr-x  1 root root       20344 Oct 31  2018 mapscrn
# -rwxr-xr-x  1 root root        1014 Oct 15  2017 markdown_py
# -rwxr-xr-x  1 root root       15808 Dec  3 01:46 mcookie
# -rwxr-xr-x  1 root root       41504 Aug 20  2019 md5sum
# -rwxr-xr-x  1 root root       66936 Jul 27  2015 memaslap
# -rwxr-xr-x  1 root root       59096 Jul 27  2015 memcapable
# -rwxr-xr-x  1 root root       20472 Jul 27  2015 memcat
# -rwxr-xr-x  1 root root       20672 Jul 27  2015 memcp
# -rwxr-xr-x  1 root root       16192 Jul 27  2015 memdump
# -rwxr-xr-x  1 root root       15832 Jul 27  2015 memerror
# -rwxr-xr-x  1 root root       16096 Jul 27  2015 memexist
# -rwxr-xr-x  1 root root       16112 Jul 27  2015 memflush
# -rwxr-xr-x  1 root root       11328 Jul 27  2015 memparse
# -rwxr-xr-x  1 root root       16216 Jul 27  2015 memping
# -rwxr-xr-x  1 root root       16160 Jul 27  2015 memrm
# -rwxr-xr-x  1 root root       25144 Jul 27  2015 memslap
# -rwxr-xr-x  1 root root       20656 Jul 27  2015 memstat
# -rwxr-xr-x  1 root root       16184 Jul 27  2015 memtouch
# -rwxr-xr-x. 1 root root       11240 Jun 10  2014 mesg
# -rwxr-xr-x  1 root root      292600 Oct 31  2018 mf
# -rwxr-xr-x  1 root root      287848 Oct 31  2018 mf-nowin
# -rwxr-xr-x  1 root root       53024 Oct 31  2018 mft
# -rwxr-xr-x. 1 root root       15744 Nov  6  2016 mixartloader
# -rwxr-xr-x  1 root root       79768 Aug 20  2019 mkdir
# -rwxr-xr-x  1 root root       63056 Aug 20  2019 mkfifo
# -rwxr-xr-x  1 root root          65 Oct 31  2018 mkfontdir
# -rwxr-xr-x  1 root root       33256 Oct 31  2018 mkfontscale
# -rwxr-xr-x  1 root root         947 Oct 31  2018 mkindex
# -rwxr-xr-x  1 root root        3013 Aug  9  2019 mkinitrd
# lrwxrwxrwx  1 root root          67 Feb 10 18:07 mkluatexfontdb -> /usr/share/texlive/texmf-dist/scripts/luaotfload/mkluatexfontdb.lua
# -rwxr-xr-x  1 root root       67184 Aug 20  2019 mknod
# -rwxr-xr-x  1 root root         171 Oct 31  2018 mkocp
# -rwxr-xr-x  1 root root          85 Oct 31  2018 mkofm
# -rwxr-xr-x  1 root root        5691 Jun 24  2015 mkpasswd
# -rwxr-xr-x  1 root root       41632 Aug 20  2019 mktemp
# lrwxrwxrwx  1 root root           7 Feb 10 18:07 mktexfmt -> fmtutil
# -rwxr-xr-x  1 root root        7564 Oct 31  2018 mktexlsr
# -rwxr-xr-x  1 root root        3814 Oct 31  2018 mktexmf
# -rwxr-xr-x  1 root root        9736 Oct 31  2018 mktexpk
# -rwxr-xr-x  1 root root        4856 Oct 31  2018 mktextfm
# -rwxr-xr-x  1 root root      161480 Dec 11 04:48 modutil
# -rwxr-xr-x  1 root root       41112 Dec  3 01:46 more
# -rwsr-xr-x  1 root root       44264 Dec  3 01:46 mount
# -rwxr-xr-x  1 root root       15688 Dec  3 01:46 mountpoint
# -rwxr-xr-x  1 root root       53792 Aug  9  2019 mpstat
# lrwxrwxrwx  1 root root          61 Feb 10 18:08 mptopdf -> /usr/share/texlive/texmf-dist/scripts/context/perl/mptopdf.pl
# -rwxr-xr-x. 1 root root       23920 Aug  3  2017 msgattrib
# -rwxr-xr-x. 1 root root       23880 Aug  3  2017 msgcat
# -rwxr-xr-x. 1 root root       24144 Aug  3  2017 msgcmp
# -rwxr-xr-x. 1 root root       23872 Aug  3  2017 msgcomm
# -rwxr-xr-x. 1 root root       19760 Aug  3  2017 msgconv
# -rwxr-xr-x. 1 root root       19752 Aug  3  2017 msgen
# -rwxr-xr-x. 1 root root       15696 Aug  3  2017 msgexec
# -rwxr-xr-x. 1 root root       28224 Aug  3  2017 msgfilter
# -rwxr-xr-x. 1 root root       78984 Aug  3  2017 msgfmt
# -rwxr-xr-x. 1 root root       36816 Aug  3  2017 msggrep
# -rwxr-xr-x. 1 root root       12751 Mar 15  2017 msghack
# -rwxr-xr-x. 1 root root       45440 Aug  3  2017 msginit
# -rwxr-xr-x. 1 root root       53848 Aug  3  2017 msgmerge
# -rwxr-xr-x. 1 root root       32448 Aug  3  2017 msgunfmt
# -rwxr-xr-x. 1 root root       19776 Aug  3  2017 msguniq
# -rwxr-xr-x  1 root root        1446 Aug  8  2019 msql2mysql
# -rwxr-xr-x  1 root root      130360 Aug 20  2019 mv
# -rwxr-xr-x  1 root root     3422080 Aug  8  2019 myisamchk
# -rwxr-xr-x  1 root root     3297968 Aug  8  2019 myisam_ftdump
# -rwxr-xr-x  1 root root     3280120 Aug  8  2019 myisamlog
# -rwxr-xr-x  1 root root     3323192 Aug  8  2019 myisampack
# -rwxr-xr-x  1 root root     2918024 Aug  8  2019 my_print_defaults
# -rwxr-xr-x  1 root root     3539560 Aug  8  2019 mysql
# -rwxr-xr-x  1 root root      111971 Aug  8  2019 mysqlaccess
# -rwxr-xr-x  1 root root     3096672 Aug  8  2019 mysqladmin
# -rwxr-xr-x  1 root root     3259992 Aug  8  2019 mysqlbinlog
# lrwxrwxrwx  1 root root          26 Jan 14 14:59 mysqlbug -> /etc/alternatives/mysqlbug
# -rwxr-xr-x  1 root root     3094152 Aug  8  2019 mysqlcheck
# lrwxrwxrwx  1 root root          30 Jan 14 14:59 mysql_config -> /etc/alternatives/mysql_config
# -rwxr-xr-x  1 root root        4215 Aug  8  2019 mysql_convert_table_format
# -rwxr-xr-x  1 root root       24116 Aug  8  2019 mysqld_multi
# -rwxr-xr-x  1 root root       26991 Aug  8  2019 mysqld_safe
# -rwxr-xr-x  1 root root     2887224 Aug  8  2019 mysqld_safe_helper
# -rwxr-xr-x  1 root root     3176784 Aug  8  2019 mysqldump
# -rwxr-xr-x  1 root root        7876 Aug  8  2019 mysqldumpslow
# -rwxr-xr-x  1 root root        3288 Aug  8  2019 mysql_find_rows
# -rwxr-xr-x  1 root root        1246 Aug  8  2019 mysql_fix_extensions
# -rwxr-xr-x  1 root root       34942 Aug  8  2019 mysqlhotcopy
# -rwxr-xr-x  1 root root     3089016 Aug  8  2019 mysqlimport
# -rwxr-xr-x  1 root root       17190 Aug  8  2019 mysql_install_db
# -rwxr-xr-x  1 root root     2926184 Aug  8  2019 mysql_plugin
# -rwxr-xr-x  1 root root       12126 Aug  8  2019 mysql_secure_installation
# -rwxr-xr-x  1 root root       17464 Aug  8  2019 mysql_setpermission
# -rwxr-xr-x  1 root root     3087552 Aug  8  2019 mysqlshow
# -rwxr-xr-x  1 root root     3106936 Aug  8  2019 mysqlslap
# -rwxr-xr-x  1 root root     3449056 Aug  8  2019 mysqltest
# -rwxr-xr-x  1 root root     2921504 Aug  8  2019 mysql_tzinfo_to_sql
# -rwxr-xr-x  1 root root     2998496 Aug  8  2019 mysql_upgrade
# -rwxr-xr-x  1 root root     2913088 Aug  8  2019 mysql_waitpid
# -rwxr-xr-x  1 root root        3856 Aug  8  2019 mysql_zap
# lrwxrwxrwx  1 root root          15 Feb 10 18:00 nail -> ../../bin/mailx
# -rwxr-xr-x  1 root root       28616 Dec  3 01:46 namei
# -rwxr-xr-x  1 root root      205904 Jun 10  2014 nano
# lrwxrwxrwx  1 root root          30 Feb 10 18:00 native2ascii -> /etc/alternatives/native2ascii
# -rwxr-xr-x  1 root root        5814 Sep  7  2017 ncurses5-config
# -rwxr-xr-x  1 root root        5817 Sep  7  2017 ncursesw5-config
# -rwxr-xr-x  1 root root       24192 Aug  9  2019 ndptool
# -rwxr-xr-x  1 root root        8347 Aug  9  2019 needs-restarting
# -rwxr-xr-x. 1 root root         271 Jun 10  2014 neqn
# -rwxr-xr-x  1 root root      155008 Aug  9  2019 netstat
# -rwxr-xr-x  1 root root       11592 Nov  6  2016 nettle-hash
# -rwxr-xr-x  1 root root        7208 Nov  6  2016 nettle-lfib-stream
# lrwxrwxrwx  1 root root          32 Feb 10 17:59 newaliases -> /etc/alternatives/mta-newaliases
# lrwxrwxrwx  1 root root          31 Feb 10 17:59 newaliases.postfix -> ../../usr/sbin/sendmail.postfix
# -rwxr-xr-x  1 root root       39000 Aug  9  2019 newgidmap
# -rwsr-xr-x  1 root root       41936 Aug  9  2019 newgrp
# -rwxr-xr-x  1 root root       38976 Aug  9  2019 newuidmap
# -rwxr-xr-x. 1 root root       12088 Aug  4  2017 nf-ct-add
# -rwxr-xr-x. 1 root root       16216 Aug  4  2017 nf-ct-list
# -rwxr-xr-x. 1 root root       16600 Aug  4  2017 nf-exp-add
# -rwxr-xr-x. 1 root root       16376 Aug  4  2017 nf-exp-delete
# -rwxr-xr-x. 1 root root       12088 Aug  4  2017 nf-exp-list
# -rwxr-xr-x. 1 root root       11504 Aug  4  2017 nf-log
# -rwxr-xr-x. 1 root root       11448 Aug  4  2017 nf-monitor
# -rwxr-xr-x. 1 root root       11544 Aug  4  2017 nf-queue
# -rwxr-xr-x  1 root root       53784 Aug  9  2019 nfsiostat-sysstat
# -rwxr-xr-x. 1 root root       36816 Aug  3  2017 ngettext
# -rwxr-xr-x  1 root root         560 Oct  3 13:12 nginx-upgrade
# -rwxr-xr-x  1 root root       33096 Aug 20  2019 nice
# lrwxrwxrwx  1 root root           8 Feb 10 17:59 nisdomainname -> hostname
# -rwxr-xr-x  1 root root       41576 Aug 20  2019 nl
# -rwxr-xr-x. 1 root root       11928 Aug  4  2017 nl-addr-add
# -rwxr-xr-x. 1 root root       12016 Aug  4  2017 nl-addr-delete
# -rwxr-xr-x. 1 root root       16256 Aug  4  2017 nl-addr-list
# -rwxr-xr-x. 2 root root       11976 Aug  4  2017 nl-class-add
# -rwxr-xr-x. 2 root root       11824 Aug  4  2017 nl-class-delete
# -rwxr-xr-x. 2 root root       11560 Aug  4  2017 nl-classid-lookup
# -rwxr-xr-x. 2 root root       11752 Aug  4  2017 nl-class-list
# -rwxr-xr-x. 2 root root       12040 Aug  4  2017 nl-cls-add
# -rwxr-xr-x. 2 root root       11960 Aug  4  2017 nl-cls-delete
# -rwxr-xr-x. 2 root root       11856 Aug  4  2017 nl-cls-list
# -rwxr-xr-x. 1 root root       11688 Aug  4  2017 nl-fib-lookup
# -rwxr-xr-x. 1 root root        7216 Aug  4  2017 nl-link-enslave
# -rwxr-xr-x. 1 root root        7232 Aug  4  2017 nl-link-ifindex2name
# -rwxr-xr-x. 2 root root       11800 Aug  4  2017 nl-link-list
# -rwxr-xr-x. 1 root root        7216 Aug  4  2017 nl-link-name2ifindex
# -rwxr-xr-x. 1 root root        7216 Aug  4  2017 nl-link-release
# -rwxr-xr-x. 1 root root       11920 Aug  4  2017 nl-link-set
# -rwxr-xr-x. 1 root root       11664 Aug  4  2017 nl-link-stats
# -rwxr-xr-x. 1 root root       11344 Aug  4  2017 nl-list-caches
# -rwxr-xr-x. 1 root root        7232 Aug  4  2017 nl-list-sockets
# -rwxr-xr-x. 1 root root       11464 Aug  4  2017 nl-monitor
# -rwxr-xr-x. 1 root root       11784 Aug  4  2017 nl-neigh-add
# -rwxr-xr-x. 1 root root       11848 Aug  4  2017 nl-neigh-delete
# -rwxr-xr-x. 1 root root       11736 Aug  4  2017 nl-neigh-list
# -rwxr-xr-x. 1 root root       11536 Aug  4  2017 nl-neightbl-list
# -rwxr-xr-x. 2 root root       11632 Aug  4  2017 nl-pktloc-lookup
# -rwxr-xr-x. 2 root root       11880 Aug  4  2017 nl-qdisc-add
# -rwxr-xr-x. 2 root root       11816 Aug  4  2017 nl-qdisc-delete
# -rwxr-xr-x. 2 root root       11904 Aug  4  2017 nl-qdisc-list
# -rwxr-xr-x. 1 root root       12016 Aug  4  2017 nl-route-add
# -rwxr-xr-x. 1 root root       16240 Aug  4  2017 nl-route-delete
# -rwxr-xr-x. 1 root root       11448 Aug  4  2017 nl-route-get
# -rwxr-xr-x. 1 root root       12056 Aug  4  2017 nl-route-list
# -rwxr-xr-x. 1 root root       11568 Aug  4  2017 nl-rule-list
# -rwxr-xr-x. 1 root root       11808 Aug  4  2017 nl-tctree-list
# -rwxr-xr-x. 1 root root        7200 Aug  4  2017 nl-util-addr
# -rwxr-xr-x  1 root root       42392 Feb  5 00:35 nm
# -rwxr-xr-x  1 root root      824456 Feb  5 01:01 nmcli
# -rwxr-xr-x  1 root root       15528 Feb  5 01:01 nm-online
# -rwxr-xr-x  1 root root      658208 Feb  5 01:01 nmtui
# lrwxrwxrwx  1 root root           5 Feb 10 17:59 nmtui-connect -> nmtui
# lrwxrwxrwx  1 root root           5 Feb 10 17:59 nmtui-edit -> nmtui
# lrwxrwxrwx  1 root root           5 Feb 10 17:59 nmtui-hostname -> nmtui
# -rwxr-xr-x  1 root root    16883856 Jun 18  2019 node
# -rwxr-xr-x  1 root root       33200 Aug 20  2019 nohup
# lrwxrwxrwx  1 root root          38 Feb 10 23:15 npm -> ../lib/node_modules/npm/bin/npm-cli.js
# -rwxr-xr-x  1 root root       33144 Aug 20  2019 nproc
# -rwxr-xr-x. 1 root root        3392 Jun 10  2014 nroff
# -rwxr-xr-x  1 root root       28896 Dec  3 01:46 nsenter
# -rwxr-xr-x  1 root root       11472 Dec 11 04:48 nss-policy-check
# -rwxr-xr-x  1 root root        6514 Aug  8  2019 ntpstat
# -rwxr-xr-x  1 root root       66264 Aug 20  2019 numfmt
# -rwxr-xr-x  1 root root      232800 Feb  5 00:35 objcopy
# -rwxr-xr-x  1 root root      366272 Feb  5 00:35 objdump
# -rwxr-xr-x  1 root root       66368 Aug 20  2019 od
# -rwxr-xr-x  1 root root      190880 Oct 31  2018 oldfind
# lrwxrwxrwx  1 root root           6 Feb 10 17:59 open -> openvt
# -rwxr-xr-x  1 root root      555288 Aug  9  2019 openssl
# -rwxr-xr-x  1 root root       20024 Oct 31  2018 openvt
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 orbd -> /etc/alternatives/orbd
# -rwxr-xr-x. 1 root root        5643 Nov  6  2016 os-prober
# lrwxrwxrwx  1 root root          35 Nov 28  2017 osscmd -> /usr/local/aliyun-cli/osscmd/osscmd
# lrwxrwxrwx  1 root root          37 Nov 28  2017 ossutil -> /usr/local/aliyun-cli/ossutil/ossutil
# -rwxr-xr-x. 1 root root       32952 Aug  5  2017 p11-kit
# lrwxrwxrwx  1 root root          25 Feb 10 18:00 pack200 -> /etc/alternatives/pack200
# -rwxr-xr-x  1 root root       17803 Aug  9  2019 package-cleanup
# -rwxr-xr-x  1 root root       11368 Sep 14 02:03 pango-list
# lrwxrwxrwx  1 root root          13 Feb 10 17:59 pango-querymodules-64 -> /usr/bin/true
# -rwxr-xr-x  1 root root       50656 Sep 14 02:03 pango-view
# -rwxr-xr-x  1 root root       11488 Jun 10  2014 paperconf
# -rwxr-xr-x  1 root root        4737 Jun 24  2015 passmass
# -rwsr-xr-x  1 root root       27856 Aug  9  2019 passwd
# -rwxr-xr-x  1 root root       33128 Aug 20  2019 paste
# -rwxr-xr-x  1 root root      150528 Oct 23 07:59 patch
# -rwxr-xr-x  1 root root       33088 Aug 20  2019 pathchk
# lrwxrwxrwx  1 root root          21 Oct 15  2017 pax -> /etc/alternatives/pax
# -rwxr-xr-x. 1 root root        4024 Nov  6  2016 pchrt
# -rwxr-xr-x  1 root root        1950 Aug  3  2017 pcre2-config
# -rwxr-xr-x  1 root root        2138 Aug  2  2017 pcre-config
# -rwxr-xr-x  1 root root      180160 Dec 25  2015 pdcp
# -rwxr-xr-x  1 root root         698 Dec  3 01:54 pdf2dsc
# -rwxr-xr-x  1 root root         909 Dec  3 01:54 pdf2ps
# -rwxr-xr-x  1 root root       16552 Aug  9  2019 pdfdetach
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 pdfetex -> pdftex
# -rwxr-xr-x  1 root root       16008 Aug  9  2019 pdffonts
# -rwxr-xr-x  1 root root       45672 Aug  9  2019 pdfimages
# -rwxr-xr-x  1 root root       28920 Aug  9  2019 pdfinfo
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 pdflatex -> pdftex
# -rwxr-xr-x  1 root root       15888 Aug  9  2019 pdfseparate
# -rwxr-xr-x  1 root root      732632 Oct 31  2018 pdftex
# -rwxr-xr-x  1 root root        1302 Mar 13  2013 pdftexi2dvi
# -rwxr-xr-x  1 root root      123344 Aug  9  2019 pdftocairo
# -rwxr-xr-x  1 root root       92400 Aug  9  2019 pdftohtml
# -rwxr-xr-x  1 root root       20112 Aug  9  2019 pdftoppm
# -rwxr-xr-x  1 root root       20248 Aug  9  2019 pdftops
# -rwxr-xr-x  1 root root       28752 Aug  9  2019 pdftotext
# -rwxr-xr-x  1 root root       20256 Aug  9  2019 pdfunite
# -rwxr-xr-x  1 root root      180160 Dec 25  2015 pdsh
# -rwxr-xr-x  1 root root       11480 Aug  9  2019 peekfd
# -rwxr-xr-x  2 root root       11488 Jan 22  2019 perl
# -rwxr-xr-x  2 root root       11488 Jan 22  2019 perl5.16.3
# -rwxr-xr-x  2 root root       44351 Jan 22  2019 perlbug
# ...
# ---x--s--x  1 root nobody    382216 Aug  9  2019 ssh-agent
# -rwxr-xr-x  1 root root       10469 Aug  9  2019 ssh-copy-id
# -rwxr-xr-x  1 root root       84208 Aug 16  2018 sshfs
# -rwxr-xr-x  1 root root      419208 Aug  9  2019 ssh-keygen
# -rwxr-xr-x  1 root root      441024 Aug  9  2019 ssh-keyscan
# -rwxr-xr-x  1 root root       15736 Sep  8  2017 sshpass
# -rwxr-xr-x  1 root root      112928 Dec 11 04:48 ssltap
# -rwxr-xr-x  1 root root       79040 Aug 20  2019 stat
# -rwxr-xr-x  1 root root       66440 Aug 20  2019 stdbuf
# -rwxr-xr-x  1 root root      650272 Oct 31  2018 strace
# -rwxr-xr-x  1 root root         944 Oct 31  2018 strace-log-merge
# -rwxr-xr-x  1 root root       29112 Feb  5 00:35 strings
# -rwxr-xr-x  1 root root      232800 Feb  5 00:35 strip
# -rwxr-xr-x  1 root root       70256 Aug 20  2019 stty
# -rwsr-xr-x  1 root root       32128 Dec  3 01:46 su
# ---s--x--x  1 root root      147320 Oct 24 23:27 sudo
# lrwxrwxrwx  1 root root           4 Feb 10 17:59 sudoedit -> sudo
# ---x--x--x  1 root root       57456 Oct 24 23:27 sudoreplay
# -rwxr-xr-x  1 root root       37432 Aug 20  2019 sum
# -rwxr-xr-x  3 root root       80872 Jun 10  2014 sx
# -rwxr-xr-x  1 root root       28976 Aug 20  2019 sync
# -rwxr-xr-x  1 root root      717568 Feb  5 00:30 systemctl
# -rwxr-xr-x  1 root root     1558000 Feb  5 00:30 systemd-analyze
# -rwxr-xr-x  1 root root       61824 Feb  5 00:30 systemd-ask-password
# -rwxr-xr-x  1 root root       40952 Feb  5 00:30 systemd-cat
# -rwxr-xr-x  1 root root      334112 Feb  5 00:30 systemd-cgls
# -rwxr-xr-x  1 root root       87128 Feb  5 00:30 systemd-cgtop
# lrwxrwxrwx  1 root root          11 Feb 10 17:59 systemd-coredumpctl -> coredumpctl
# -rwxr-xr-x  1 root root       78680 Feb  5 00:30 systemd-delta
# -rwxr-xr-x  1 root root       40928 Feb  5 00:30 systemd-detect-virt
# -rwxr-xr-x  1 root root       49352 Feb  5 00:30 systemd-escape
# -rwxr-xr-x  1 root root      103952 Feb  5 00:30 systemd-firstboot
# -rwxr-xr-x  1 root root       87344 Feb  5 00:30 systemd-hwdb
# -rwxr-xr-x  1 root root      313200 Feb  5 00:30 systemd-inhibit
# lrwxrwxrwx  1 root root           8 Feb 10 17:59 systemd-loginctl -> loginctl
# -rwxr-xr-x  1 root root       53488 Feb  5 00:30 systemd-machine-id-setup
# -rwxr-xr-x  1 root root       49288 Feb  5 00:30 systemd-notify
# -rwxr-xr-x  1 root root      558912 Feb  5 00:30 systemd-nspawn
# -rwxr-xr-x  1 root root       53416 Feb  5 00:30 systemd-path
# -rwxr-xr-x  1 root root      392216 Feb  5 00:30 systemd-run
# -rwxr-xr-x  1 root root      313136 Feb  5 00:30 systemd-stdio-bridge
# -rwxr-xr-x  1 root root        3979 Feb  5 00:29 systemd-sysv-convert
# -rwxr-xr-x  1 root root      145536 Feb  5 00:30 systemd-tmpfiles
# -rwxr-xr-x  1 root root       86784 Feb  5 00:30 systemd-tty-ask-password-agent
# -rwxr-xr-x  3 root root       80872 Jun 10  2014 sz
# -rwxr-xr-x  1 root root       15680 Sep  7  2017 tabs
# -rwxr-xr-x  1 root root       33264 Aug 20  2019 tac
# -rwxr-xr-x  1 root root       66824 Aug 20  2019 tail
# -rwxr-xr-x  1 root root       24456 Dec  3 01:46 tailf
# -rwxr-xr-x  1 root root       53816 Aug  9  2019 tapestat
# -rwxr-xr-x  1 root root      346136 Oct 31  2018 tar
# -rwxr-xr-x  1 root root       32992 Dec  3 01:46 taskset
# -rwxr-xr-x. 1 root root      118744 Jun 10  2014 tbl
# lrwxrwxrwx  1 root root           8 Nov  2  2017 tclsh -> tclsh8.5
# -rwxr-xr-x  1 root root        7168 Nov 20  2015 tclsh8.5
# -rwxr-xr-x  1 root root      154648 Aug  9  2019 teamd
# -rwxr-xr-x  1 root root       29672 Aug  9  2019 teamdctl
# -rwxr-xr-x  1 root root       19560 Aug  9  2019 teamnl
# -rwxr-xr-x  1 root root       11432 Jun 10  2014 teckit_compile
# -rwxr-xr-x  1 root root       33160 Aug 20  2019 tee
# -rwxr-xr-x  1 root root      101776 Aug  4  2017 telnet
# -rwxr-xr-x  1 root root       37336 Aug 20  2019 test
# -rwxr-xr-x. 1 root root       30488 Jun 10  2014 testgdbm
# -rwxr-xr-x  1 root root      320952 Oct 31  2018 tex
# lrwxrwxrwx  1 root root          51 Feb 10 18:07 texconfig -> /usr/share/texlive/texmf/scripts/tetex/texconfig.sh
# lrwxrwxrwx  1 root root          58 Feb 10 18:08 texconfig-dialog -> /usr/share/texlive/texmf/scripts/tetex/texconfig-dialog.sh
# lrwxrwxrwx  1 root root          55 Feb 10 18:08 texconfig-sys -> /usr/share/texlive/texmf/scripts/tetex/texconfig-sys.sh
# lrwxrwxrwx  1 root root           8 Feb 10 18:07 texhash -> mktexlsr
# -rwxr-xr-x  1 root root       52045 Apr 11  2018 texi2any
# -rwxr-xr-x  1 root root       58067 Mar 13  2013 texi2dvi
# -rwxr-xr-x  1 root root        1302 Mar 13  2013 texi2pdf
# -rwxr-xr-x  1 root root       20424 Apr 11  2018 texindex
# lrwxrwxrwx  1 root root          50 Feb 10 18:08 texlinks -> /usr/share/texlive/texmf/scripts/tetex/texlinks.sh
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 texlua -> luatex
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 texluac -> luatex
# lrwxrwxrwx  1 root root          58 Feb 10 18:07 thumbpdf -> /usr/share/texlive/texmf-dist/scripts/thumbpdf/thumbpdf.pl
# -rwxr-xr-x  1 root root       65800 Sep  7  2017 tic
# -rwxr-xr-x  1 root root       15920 Jun 12  2014 time
# -rwxr-xr-x  1 root root      338104 Feb  5 00:30 timedatectl
# -rwxr-xr-x  1 root root         303 Jun 24  2015 timed-read
# -rwxr-xr-x  1 root root         277 Jun 24  2015 timed-run
# -rwxr-xr-x  1 root root       54592 Aug 20  2019 timeout
# -rwxr-xr-x  1 root root       15744 Oct 19 00:08 tload
# -rwxr-xr-x  1 root root       31856 Feb  5 07:13 tmon
# -rwxr-xr-x  1 root root      631736 May 25  2019 tmux
# lrwxrwxrwx  1 root root          27 Feb 10 18:00 tnameserv -> /etc/alternatives/tnameserv
# -rwxr-xr-x  1 root root       15800 Sep  7  2017 toe
# -rwxr-xr-x  1 root root      106880 Oct 19 00:08 top
# -rwxr-xr-x  1 root root       62480 Aug 20  2019 touch
# -rwxr-xr-x  1 root root       15784 Sep  7  2017 tput
# -rwxr-xr-x  1 root root         213 Jan 28  2018 tqdm
# -rwxr-xr-x  1 root root       45680 Aug 20  2019 tr
# -rwxr-xr-x. 1 root root       15408 Aug  4  2017 tracepath
# -rwxr-xr-x. 1 root root       15408 Aug  4  2017 tracepath6
# -rwxr-xr-x  1 root root       62768 Jun 10  2014 tree
# -rwxr-xr-x. 1 root root      525272 Jun 10  2014 troff
# -rwxr-xr-x  1 root root       28936 Aug 20  2019 true
# -rwxr-xr-x  1 root root       53936 Aug 20  2019 truncate
# -rwxr-xr-x. 1 root root      183376 Aug  5  2017 trust
# -rwxr-xr-x  1 root root       20072 Sep  7  2017 tset
# -rwxr-xr-x  1 root root       37344 Aug 20  2019 tsort
# -rwxr-xr-x  1 root root      101416 Nov 20  2015 ttmkfdir
# -rwxr-xr-x  1 root root       28968 Aug 20  2019 tty
# -rwxr-xr-x  1 root root      115864 Feb  5 07:13 turbostat
# -rwxr-xr-x  1 root root       15576 Jun 10  2014 txtconv
# -rwxr-xr-x  1 root root        7339 Aug  7  2019 tzselect
# -rwxr-xr-x  1 root root       19936 Oct 31  2018 ucs2any
# -rwxr-xr-x  1 root root      424208 Feb  5 00:30 udevadm
# -rwxr-xr-x  1 root root       19936 Dec  3 01:46 ul
# -rwxr-xr-x  1 root root       15472 Oct 31  2018 ulockmgr_server
# -rwxr-xr-x  1 root root          29 Aug  8  2019 umask
# -rwsr-xr-x  1 root root       31984 Dec  3 01:46 umount
# -rwxr-xr-x  1 root root          31 Aug  8  2019 unalias
# -rwxr-xr-x  1 root root       33080 Aug 20  2019 uname
# -rwxr-xr-x  1 root root     2343960 Jun 10  2016 unar
# -rwxr-xr-x  1 root root         640 Jun 24  2015 unbuffer
# -rwxr-xr-x  1 root root       33232 Aug 20  2019 unexpand
# -rwxr-xr-x  1 root root        2555 Oct 31  2018 unicode_start
# -rwxr-xr-x  1 root root         363 Oct 31  2018 unicode_stop
# -rwxr-xr-x  1 root root       45784 Aug 20  2019 uniq
# -rwxr-xr-x  1 root root        4165 Dec  3 01:54 unix-lpr.sh
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 unlink
# lrwxrwxrwx  1 root root           3 Jan 14 09:55 unlz4 -> lz4
# lrwxrwxrwx  1 root root          27 Feb 10 18:00 unpack200 -> /etc/alternatives/unpack200
# -rwxr-xr-x  1 root root       15824 Dec  3 01:46 unshare
# lrwxrwxrwx. 1 root root           2 Oct 15  2017 unxz -> xz
# -rwxr-xr-x  2 root root      185472 Aug  9  2019 unzip
# -rwxr-xr-x  1 root root       90752 Aug  9  2019 unzipsfx
# -rwxr-xr-x  1 root root        1054 Nov 27 23:33 update-ca-trust
# -rwxr-xr-x  1 root root       48792 Apr 11  2018 updatedb
# -rwxr-xr-x  1 root root       20168 Aug  9  2019 update-desktop-database
# -rwxr-xr-x  1 root root         313 Aug  2  2017 update-gtk-immodules
# -rwxr-xr-x  1 root root       54080 Apr 11  2018 update-mime-database
# lrwxrwxrwx  1 root root          53 Feb 10 18:08 updmap -> /usr/share/texlive/texmf-dist/scripts/tetex/updmap.pl
# lrwxrwxrwx  1 root root          57 Feb 10 18:08 updmap-sys -> /usr/share/texlive/texmf-dist/scripts/tetex/updmap-sys.sh
# -rwxr-xr-x  1 root root       11488 Oct 19 00:08 uptime
# -rwxr-xr-x  1 root root       12465 Oct 31  2018 urlgrabber
# -rwxr-xr-x  1 root root       33200 Aug 20  2019 users
# -rwxr-xr-x  1 root root       11208 Aug  9  2019 usleep
# -rwxr-xr-x. 1 root root       15776 Nov  6  2016 usx2yloader
# -rwxr-xr-x  1 root root       15816 Dec  3 01:46 utmpdump
# -rwxr-xr-x  1 root root       15328 Sep 14 02:05 uuclient
# -rwxr-xr-x  1 root root       11480 Dec  3 01:46 uuidgen
# -rwxr-xr-x  1 root root      117608 Aug 20  2019 vdir
# -rwxr-xr-x  1 root root       11046 Aug  9  2019 verifytree
# -rwxr-xr-x  1 root root      928184 Aug  9  2019 vi
# lrwxrwxrwx  1 root root           2 Feb 10 17:59 view -> vi
# -rwxr-xr-x  1 root root     2337192 Aug  9  2019 vim
# lrwxrwxrwx  1 root root           3 Feb 10 17:59 vimdiff -> vim
# -rwxr-xr-x  1 root root        2084 Aug  9  2019 vimtutor
# -rwxr-xr-x  1 root root         213 Jan 29  2018 virtualenv
# -rwxr-xr-x  1 root root       16160 Oct 31  2018 vlock
# -rwxr-xr-x  1 root root       32232 Oct 19 00:08 vmstat
# -rwxr-xr-x. 1 root root       15744 Nov  6  2016 vxloader
# -rwxr-xr-x  1 root root       19912 Oct 19 00:08 w
# -rwxr-xr-x  1 root root          28 Aug  8  2019 wait
# -r-xr-sr-x. 1 root tty        15344 Jun 10  2014 wall
# -rwxr-xr-x  1 root root       24728 Oct 19 00:08 watch
# -rwxr-xr-x  1 root root       15720 Jul 13  2018 watchgnupg
# -rwxr-xr-x  1 root root       41648 Aug 20  2019 wc
# -rwxr-xr-x  1 root root       41672 Dec  3 01:46 wdctl
# -rwxr-xr-x  1 root root        2237 Jun 24  2015 weather
# -rwxr-xr-x  1 root root      418776 May 16  2019 wget
# -rwxr-xr-x  1 root root       46584 Oct 31  2018 whatis
# lrwxrwxrwx  1 root root           7 Feb 10 18:00 wheel -> wheel-2
# lrwxrwxrwx  1 root root           9 Feb 10 18:00 wheel-2 -> wheel-2.7
# -rwxr-xr-x  1 root root         295 Aug  8  2019 wheel-2.7
# -rwxr-xr-x  1 root root       20680 Dec  3 01:46 whereis
# -rwxr-xr-x. 1 root root       24336 Jun 10  2014 which
# -rwxr-xr-x. 1 root root       28504 Jun 10  2014 whiptail
# -rwxr-xr-x  1 root root       49872 Aug 20  2019 who
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 whoami
# lrwxrwxrwx  1 root root           7 Feb 10 18:07 wish -> wish8.5
# -rwxr-xr-x  1 root root        7208 Nov 20  2015 wish8.5
# -rwxr-xr-x  1 root root         229 Nov  6  2016 withsctp
# -rwxr-sr-x  1 root tty        19544 Dec  3 01:46 write
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 wsgen -> /etc/alternatives/wsgen
# lrwxrwxrwx  1 root root          26 Feb 10 18:00 wsimport -> /etc/alternatives/wsimport
# lrwxrwxrwx  1 root root           7 Feb 10 17:59 x86_64 -> setarch
# -rwxr-xr-x  4 root root      772744 Aug  7  2019 x86_64-redhat-linux-c++
# -rwxr-xr-x  4 root root      772744 Aug  7  2019 x86_64-redhat-linux-g++
# -rwxr-xr-x  2 root root      768648 Aug  7  2019 x86_64-redhat-linux-gcc
# -rwxr-xr-x  1 root root       10480 Feb  5 07:13 x86_energy_perf_policy
# -rwxr-xr-x  1 root root       62368 Oct 31  2018 xargs
# -rwxr-xr-x  1 root root       19511 Nov  5  2016 xdg-desktop-icon
# -rwxr-xr-x  1 root root       42913 Nov  5  2016 xdg-desktop-menu
# -rwxr-xr-x  1 root root       23964 Nov  5  2016 xdg-email
# -rwxr-xr-x  1 root root       28727 Nov  5  2016 xdg-icon-resource
# -rwxr-xr-x  1 root root       39354 Nov  5  2016 xdg-mime
# -rwxr-xr-x  1 root root       19296 Nov  5  2016 xdg-open
# -rwxr-xr-x  1 root root       28532 Nov  5  2016 xdg-screensaver
# -rwxr-xr-x  1 root root       33576 Nov  5  2016 xdg-settings
# -rwxr-xr-x  1 root root        1863 Oct 31  2018 xdvi
# -rwxr-xr-x  1 root root      648120 Oct 31  2018 xdvipdfmx
# -rwxr-xr-x  1 root root      642520 Oct 31  2018 xdvi-xaw
# lrwxrwxrwx  1 root root           5 Feb 11 18:40 xelatex -> xetex
# -rwxr-xr-x  1 root root      558040 Oct 31  2018 xetex
# -rwxr-xr-x  1 root root       11416 Aug 12  2017 xgamma
# -rwxr-xr-x. 1 root root      271784 Aug  3  2017 xgettext
# -rwxr-xr-x  1 root root       15752 Aug 12  2017 xhost
# -rwxr-xr-x  1 root root       54080 Aug 12  2017 xinput
# lrwxrwxrwx  1 root root          21 Feb 10 18:00 xjc -> /etc/alternatives/xjc
# -rwxr-xr-x  1 root root        4862 Jun 24  2015 xkibitz
# -rwxr-xr-x  1 root root       15632 Aug 12  2017 xkill
# -rwxr-xr-x. 1 root root       19752 Jun 23  2016 xmlcatalog
# -rwxr-xr-x. 1 root root       63408 Jun 23  2016 xmllint
# -rwxr-xr-x. 1 root root       24568 Nov 29  2016 xmlwf
# -rwxr-xr-x  1 root root       33056 Aug 12  2017 xmodmap
# -rwxr-xr-x  1 root root        1063 Nov 21  2015 xmvn-builddep
# -rwxr--r--  1 root root        1322 Oct 31  2018 xorg-x11-fonts-update-dirs
# -rwxr-xr-x  1 root root       61504 Aug 12  2017 xrandr
# -rwxr-xr-x  1 root root       28448 Aug 12  2017 xrdb
# -rwxr-xr-x  1 root root       11424 Aug 12  2017 xrefresh
# -rwxr-xr-x  1 root root       32480 Aug 12  2017 xset
# -rwxr-xr-x  1 root root       11368 Aug 12  2017 xsetmode
# -rwxr-xr-x  1 root root       11400 Aug 12  2017 xsetpointer
# -rwxr-xr-x  1 root root       19840 Aug 12  2017 xsetroot
# -rwxr-xr-x  1 root root       24056 Jun 10  2014 xsltproc
# -rwxr-xr-x  1 root root       16144 Aug 12  2017 xstdcmap
# -rwxr-xr-x  1 root root       14768 Aug  9  2019 xxd
# -rwxr-xr-x. 1 root root       75280 Nov  5  2016 xz
# lrwxrwxrwx. 1 root root           2 Oct 15  2017 xzcat -> xz
# lrwxrwxrwx. 1 root root           6 Oct 15  2017 xzcmp -> xzdiff
# -rwxr-xr-x. 1 root root       11472 Nov  5  2016 xzdec
# -rwxr-xr-x. 1 root root        6632 Nov  5  2016 xzdiff
# lrwxrwxrwx. 1 root root           6 Oct 15  2017 xzegrep -> xzgrep
# lrwxrwxrwx. 1 root root           6 Oct 15  2017 xzfgrep -> xzgrep
# -rwxr-xr-x. 1 root root        5628 Nov  5  2016 xzgrep
# -rwxr-xr-x. 1 root root        1802 Nov  5  2016 xzless
# -rwxr-xr-x. 1 root root        2161 Nov  5  2016 xzmore
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 yes
# lrwxrwxrwx  1 root root           8 Feb 10 17:59 ypdomainname -> hostname
# -rwxr-xr-x  1 root root         801 Aug  8  2019 yum
# -rwxr-xr-x  1 root root       10189 Aug  9  2019 yum-builddep
# -rwxr-xr-x  1 root root        9579 Aug  9  2019 yum-config-manager
# -rwxr-xr-x  1 root root        8538 Aug  9  2019 yum-debug-dump
# -rwxr-xr-x  1 root root        7903 Aug  9  2019 yum-debug-restore
# -rwxr-xr-x  1 root root       11115 Aug  9  2019 yumdownloader
# -rwxr-xr-x  1 root root       11031 Aug  9  2019 yum-groups-manager
# -rwxr-xr-x  1 root root        1941 Apr 11  2018 zcat
# -rwxr-xr-x  1 root root        1760 Apr 11  2018 zcmp
# -rwxr-xr-x  1 root root        5768 Apr 11  2018 zdiff
# -rwxr-xr-x  1 root root         123 Apr 11  2018 zegrep
# lrwxrwxrwx  1 root root          25 Nov  2  2017 zf -> /usr/share/php/Zend/zf.sh
# -rwxr-xr-x  1 root root         123 Apr 11  2018 zfgrep
# -rwxr-xr-x  1 root root        2144 Apr 11  2018 zforce
# -rwxr-xr-x  1 root root        6132 Apr 11  2018 zgrep
# -rwxr-xr-x  1 root root      215840 Nov  6  2016 zip
# -rwxr-xr-x  1 root root      100456 Nov  6  2016 zipcloak
# -rwxr-xr-x  1 root root       11992 Jun 10  2014 zipcmp
# -rwxr-xr-x  1 root root       48451 Jun 10  2014 zipdetails
# -rwxr-xr-x  1 root root        2953 Oct 11  2008 zipgrep
# -rwxr-xr-x  2 root root      185472 Aug  9  2019 zipinfo
# -rwxr-xr-x  1 root root       12040 Jun 10  2014 zipmerge
# -rwxr-xr-x  1 root root       95984 Nov  6  2016 zipnote
# -rwxr-xr-x  1 root root      100096 Nov  6  2016 zipsplit
# -rwxr-xr-x  1 root root       11880 Jun 10  2014 ziptorrent
# -rwxr-xr-x  1 root root        2041 Apr 11  2018 zless
# -rwxr-xr-x  1 root root        2859 Apr 11  2018 zmore
# -rwxr-xr-x  1 root root        5343 Apr 11  2018 znew
# lrwxrwxrwx. 1 root root           6 Oct 15  2017 zsoelim -> soelim

# %% [markdown]
# ## Append redirected output to a file

# %%
ls -l /usr/bin >> ls-output.txt

# %% [markdown]
# ## Redirecting Standard Error

# %%
ls -l /bin/usr 2> ls-error.txt
# Out:
# : 2

# %% [markdown]
# ## Redirecting Standard Input

# %%
cat ls-output.txt
# Out:
# total 393056
# -rwxr-xr-x  1 root root       41488 Aug 20  2019 [
# -rwxr-xr-x  1 root root      107904 Jan 22  2019 a2p
# -rwxr-xr-x  1 root root       52728 Aug  8  2019 ab
# -rwxr-xr-x  1 root root        1661 Nov 21  2015 abs2rel
# -rwxr-xr-x  1 root root       29104 Feb  5 00:35 addr2line
# -rwxr-xr-x  1 root root       39408 Oct 31  2018 afm2tfm
# -rwxr-xr-x  1 root root          29 Aug  8  2019 alias
# lrwxrwxrwx  1 root root          52 Feb 10 18:08 allcm -> /usr/share/texlive/texmf-dist/scripts/tetex/allcm.sh
# lrwxrwxrwx  1 root root           5 Feb 10 18:08 allec -> allcm
# lrwxrwxrwx  1 root root          56 Feb 10 18:08 allneeded -> /usr/share/texlive/texmf-dist/scripts/tetex/allneeded.sh
# lrwxrwxrwx  1 root root          30 Feb 10 18:00 appletviewer -> /etc/alternatives/appletviewer
# lrwxrwxrwx  1 root root           6 Feb 10 17:59 apropos -> whatis
# -rwxr-xr-x  1 root root       62688 Feb  5 00:35 ar
# -rwxr-xr-x  1 root root       33080 Aug 20  2019 arch
# -rwxr-xr-x  1 root root     3980664 Aug  8  2019 aria_chk
# -rwxr-xr-x  1 root root     3768592 Aug  8  2019 aria_dump_log
# -rwxr-xr-x  1 root root     3785336 Aug  8  2019 aria_ftdump
# -rwxr-xr-x  1 root root     3814808 Aug  8  2019 aria_pack
# -rwxr-xr-x  1 root root     3939600 Aug  8  2019 aria_read_log
# -rwxr-xr-x  1 root root      386416 Feb  5 00:35 as
# -rwxr-xr-x  1 root root       28888 Aug  8  2019 aserver
# -rwsr-xr-x  1 root root       53048 Oct 31  2018 at
# lrwxrwxrwx  1 root root           2 Feb 10 17:59 atq -> at
# lrwxrwxrwx  1 root root           2 Feb 10 17:59 atrm -> at
# -rwxr-xr-x  1 root root       14554 Aug  9  2019 audit2allow
# lrwxrwxrwx  1 root root          11 Jan 13 15:22 audit2why -> audit2allow
# -rwxr-xr-x  1 root root       15856 Aug  8  2019 aulast
# -rwxr-xr-x  1 root root       11624 Aug  8  2019 aulastlog
# -rwxr-xr-x  1 root root       11448 Aug  8  2019 ausyscall
# -rwxr-xr-x  1 root root        7706 Jun 24  2015 autoexpect
# -rwxr-xr-x  1 root root       32696 Aug  8  2019 auvirt
# lrwxrwxrwx. 1 root root           4 Oct 15  2017 awk -> gawk
# -rwxr-xr-x  1 root root       37360 Aug 20  2019 base64
# -rwxr-xr-x  1 root root       29032 Aug 20  2019 basename
# -rwxr-xr-x  1 root root      964600 Aug  8  2019 bash
# lrwxrwxrwx  1 root root          10 Feb 10 17:58 bashbug -> bashbug-64
# -rwxr-xr-x  1 root root        6964 Aug  8  2019 bashbug-64
# -rwxr-xr-x  1 root root         137 Oct 31  2018 batch
# -rwxr-xr-x  1 root root       83424 Jun 10  2014 bc
# -rwxr-xr-x  1 root root       45248 Oct 31  2018 bdftopcf
# -rwxr-xr-x  1 root root       11464 Oct 31  2018 bdftruncate
# -rwxr-xr-x  1 root root          26 Aug  8  2019 bg
# -rwxr-xr-x  1 root root      108512 Oct 31  2018 bibtex
# -rwxr-xr-x  1 root root       23289 Mar 18  2017 bond2team
# -rwxr-xr-x  1 root root       70648 Feb  5 00:30 bootctl
# -rwxr-xr-x  1 root root        1537 Nov 21  2015 build-classpath
# -rwxr-xr-x  1 root root         383 Nov 21  2015 build-classpath-directory
# -rwxr-xr-x  1 root root        1571 Nov 21  2015 build-jar-repository
# -rwxr-xr-x  1 root root      408680 Feb  5 00:30 busctl
# -rwxr-xr-x  4 root root      772744 Aug  7  2019 c++
# -rwxr-xr-x  2 root root       36607 Jan 22  2019 c2ph
# -rwxr-xr-x  1 root root         224 Aug  7  2019 c89
# -rwxr-xr-x  1 root root         215 Aug  7  2019 c99
# -rwxr-xr-x  1 root root       71672 Aug  9  2019 cairo-sphinx
# -rwxr-xr-x  1 root root       37688 Dec  3 01:46 cal
# -rwxr-xr-x  1 root root        1638 Nov 27 23:33 ca-legacy
# lrwxrwxrwx  1 root root          30 Feb 10 17:59 cancel -> /etc/alternatives/print-cancel
# -rwxr-xr-x  1 root root       15408 Aug  9  2019 cancel.cups
# lrwxrwxrwx  1 root root           3 Oct 15  2017 captoinfo -> tic
# -rwxr-xr-x  1 root root       54080 Aug 20  2019 cat
# -rwxr-xr-x  1 root root        3336 Aug  7  2019 catchsegv
# -rwxr-xr-x  1 root root       37632 Oct 31  2018 catman
# lrwxrwxrwx  1 root root           3 Feb 10 17:59 cc -> gcc
# -rwxr-xr-x  1 root root          26 Aug  8  2019 cd
# -rwxr-xr-x  1 root root        6280 Feb  5 07:13 centrino-decode
# -rwxr-xr-x  1 root root      175760 Dec 11 04:48 certutil
# -rwxr-xr-x  1 root root       28592 Feb  5 00:35 c++filt
# -rwxr-xr-x  1 root root       15640 Apr 11  2018 chacl
# -rwsr-xr-x  1 root root       73888 Aug  9  2019 chage
# -rwxr-xr-x  1 root root         307 Aug  9  2019 chardetect
# -rwxr-xr-x  1 root root       11616 Aug  9  2019 chattr
# -rwxr-xr-x  1 root root       13430 Aug  9  2019 chcat
# -rwxr-xr-x  1 root root       62936 Aug 20  2019 chcon
# -rwxr-xr-x  1 root root        3328 Nov 21  2015 check-binary-files
# -rwxr-xr-x  1 root root      410096 Oct 31  2018 checkmodule
# -rwxr-xr-x  1 root root      422360 Oct 31  2018 checkpolicy
# -rwxr-xr-x  1 root root        7168 Nov  6  2016 checksctp
# -rwxr-xr-x  1 root root          74 Oct 15  2017 cheetah
# -rwxr-xr-x  1 root root         115 Oct 15  2017 cheetah-analyze
# -rwxr-xr-x  1 root root          90 Oct 15  2017 cheetah-compile
# -rws--x--x  1 root root       23968 Dec  3 01:46 chfn
# -rwxr-xr-x  1 root root       62784 Aug 20  2019 chgrp
# -rwxr-xr-x  1 root root       41400 Dec  3 01:46 chmem
# -rwxr-xr-x  1 root root       58592 Aug 20  2019 chmod
# -rwxr-xr-x  1 root root       62824 Aug 20  2019 chown
# -rwxr-xr-x  1 root root       87072 Aug  8  2019 chronyc
# -rwxr-xr-x  1 root root       32944 Dec  3 01:46 chrt
# -rws--x--x  1 root root       23880 Dec  3 01:46 chsh
# -rwxr-xr-x  1 root root       11480 Oct 31  2018 chvt
# -rwxr-xr-x  1 root root       49672 Aug  9  2019 cifsiostat
# -rwxr-xr-x  1 root root       33152 Aug 20  2019 cksum
# -rwxr-xr-x  1 root root       13220 Nov 21  2015 clean-binary-files
# -rwxr-xr-x  1 root root        7192 Sep  7  2017 clear
# -rwxr-xr-x  1 root root         183 Oct 15  2017 cloud-init
# -rwxr-xr-x  1 root root        1704 Oct 15  2017 cloud-init-per
# -rwxr-xr-x  1 root root          19 Jan  6 13:23 cloud-init-upgrade
# -rwxr-xr-x  1 root root       45272 Aug  9  2019 cmp
# -rwxr-xr-x  1 root root      104912 Dec 11 04:48 cmsutil
# -rwxr-xr-x  1 root root       24448 Dec  3 01:46 col
# -rwxr-xr-x  1 root root       11560 Dec  3 01:46 colcrt
# -rwxr-xr-x  1 root root       24352 Dec  3 01:46 colrm
# -rwxr-xr-x  1 root root       28664 Dec  3 01:46 column
# -rwxr-xr-x  1 root root       37424 Aug 20  2019 comm
# -rwxr-xr-x  1 root root          31 Aug  8  2019 command
# -rwxr-xr-x  1 root root        1480 Aug  9  2019 compile_et
# lrwxrwxrwx  1 root root          71 Feb 10 23:19 configurable-http-proxy -> ../lib/node_modules/configurable-http-proxy/bin/configurable-http-proxy
# -rwxr-xr-x  1 root root      158200 Feb  5 00:30 coredumpctl
# -rwxr-xr-x  1 root root      155176 Aug 20  2019 cp
# -rwxr-xr-x  1 root root      145960 Apr 11  2018 cpio
# -rwxr-xr-x  1 root root      772720 Aug  7  2019 cpp
# -rwxr-xr-x  1 root root       67928 Feb  5 07:13 cpupower
# -rwxr-xr-x  1 root root        4657 Nov 21  2015 create-jar-links
# -rwxr-xr-x  1 root root      121744 Dec 11 04:48 crlutil
# -rwsr-xr-x  1 root root       57656 Aug  9  2019 crontab
# -rwxr-xr-x  1 root root       49992 Aug 20  2019 csplit
# -rwxr-xr-x  1 root root       20096 Oct 31  2018 csslint-0.6
# -rwxr-xr-x  1 root root       15424 Aug  9  2019 cupstestdsc
# -rwxr-xr-x  1 root root       56536 Aug  9  2019 cupstestppd
# -rwxr-xr-x  1 root root      156672 Feb  5 01:00 curl
# -rwxr-xr-x  1 root root       41576 Aug 20  2019 cut
# -rwxr-xr-x  1 root root      247440 Oct 24 23:27 cvtsudoers
# -rwxr-xr-x  1 root root       62200 Aug 20  2019 date
# -rwxr-xr-x  1 root root       11496 Aug  9  2019 db_archive
# -rwxr-xr-x  1 root root       11576 Aug  9  2019 db_checkpoint
# -rwxr-xr-x  1 root root       11584 Aug  9  2019 db_deadlock
# -rwxr-xr-x  1 root root       15696 Aug  9  2019 db_dump
# -rwxr-xr-x  1 root root       65992 Aug  9  2019 db_dump185
# -rwxr-xr-x  1 root root       15712 Aug  9  2019 db_hotbackup
# -rwxr-xr-x  1 root root        1465 Jun 10  2014 dbilogstrip
# -rwxr-xr-x  1 root root        6293 Jun 10  2014 dbiprof
# -rwxr-xr-x  1 root root        5474 Jun 10  2014 dbiproxy
# -rwxr-xr-x  1 root root       28168 Aug  9  2019 db_load
# -rwxr-xr-x  1 root root       15704 Aug  9  2019 db_log_verify
# -rwxr-xr-x  1 root root       33032 Aug  9  2019 db_printlog
# -rwxr-xr-x  1 root root       11600 Aug  9  2019 db_recover
# -rwxr-xr-x  1 root root       15712 Aug  9  2019 db_replicate
# -rwxr-xr-x  1 root root       15624 Aug  9  2019 db_stat
# -rwxr-xr-x  1 root root       19792 Aug  9  2019 db_tuner
# -rwxr-xr-x  1 root root       11504 Aug  9  2019 db_upgrade
# -rwxr-xr-x. 1 root root       96760 Jun 10  2014 dbus-binding-tool
# -rwxr-xr-x  1 root root       11344 Mar 14  2019 dbus-cleanup-sockets
# -rwxr-xr-x  1 root root      223320 Mar 14  2019 dbus-daemon
# -rwxr-xr-x  1 root root       23760 Mar 14  2019 dbus-monitor
# -rwxr-xr-x  1 root root       15408 Mar 14  2019 dbus-run-session
# -rwxr-xr-x  1 root root       27800 Mar 14  2019 dbus-send
# -rwxr-xr-x  1 root root       23768 Mar 14  2019 dbus-test-tool
# -rwxr-xr-x  1 root root       15480 Mar 14  2019 dbus-update-activation-environment
# -rwxr-xr-x  1 root root       11328 Mar 14  2019 dbus-uuidgen
# -rwxr-xr-x  1 root root       11520 Aug  9  2019 db_verify
# -rwxr-xr-x  1 root root       45392 Jun 10  2014 dc
# -rwxr-xr-x  1 root root       74896 Aug 20  2019 dd
# -rwxr-xr-x  1 root root       11496 Oct 31  2018 deallocvt
# -rwxr-xr-x  1 root root        8071 Aug  9  2019 debuginfo-install
# lrwxrwxrwx  1 root root          20 Feb 10 18:08 desktop-file-edit -> desktop-file-install
# -rwxr-xr-x  1 root root       76520 Aug  9  2019 desktop-file-install
# -rwxr-xr-x  1 root root       64184 Aug  9  2019 desktop-file-validate
# -rwxr-xr-x  1 root root      105016 Aug 20  2019 df
# -rwxr-xr-x. 1 root root      514168 Jun 29  2017 dgawk
# -rwxr-xr-x  1 root root      200224 Aug  9  2019 diff
# -rwxr-xr-x  1 root root       62200 Aug  9  2019 diff3
# -rwxr-xr-x  1 root root        1236 Nov 21  2015 diff-jars
# -rwxr-xr-x  1 root root      117608 Aug 20  2019 dir
# -rwxr-xr-x  1 root root         225 Jan 28  2018 dir2pi
# -rwxr-xr-x  1 root root       41408 Aug 20  2019 dircolors
# -rwxr-xr-x  1 root root       28992 Aug 20  2019 dirname
# -rwxr-xr-x  1 root root        7938 Jun 24  2015 dislocate
# -rwxr-xr-x  1 root root       49680 Dec  3 01:46 dmesg
# lrwxrwxrwx  1 root root           8 Feb 10 17:59 dnsdomainname -> hostname
# -rwxr-xr-x  1 root root    33061032 Jul 19  2018 docker
# -rwxr-xr-x  1 root root    38076568 Jul 19  2018 docker-containerd
# -rwxr-xr-x  1 root root    20895160 Jul 19  2018 docker-containerd-ctr
# -rwxr-xr-x  1 root root     4173632 Jul 19  2018 docker-containerd-shim
# -rwxr-xr-x  1 root root    68465264 Jul 19  2018 dockerd
# -rwxr-xr-x  1 root root      849224 Jul 19  2018 docker-init
# -rwxr-xr-x  1 root root     2411096 Jul 19  2018 docker-proxy
# -rwxr-xr-x  1 root root     7639448 Jul 19  2018 docker-runc
# lrwxrwxrwx  1 root root           8 Feb 10 17:59 domainname -> hostname
# -rwxr-xr-x  1 root root       57002 Aug  9  2019 dracut
# -rwxr-xr-x  1 root root        8638 Dec 25  2015 dshbak
# -rwxr-xr-x  1 root root      112992 Aug 20  2019 du
# -rwxr-xr-x  1 root root       79440 Oct 31  2018 dumpkeys
# lrwxrwxrwx  1 root root          54 Feb 10 18:08 dvi2fax -> /usr/share/texlive/texmf-dist/scripts/tetex/dvi2fax.sh
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 dvilualatex -> luatex
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 dviluatex -> luatex
# -rwxr-xr-x  1 root root        1026 Dec  3 01:54 dvipdf
# lrwxrwxrwx  1 root root           8 Feb 10 18:07 dvipdfm -> dvipdfmx
# -rwxr-xr-x  1 root root      617592 Oct 31  2018 dvipdfmx
# -rwxr-xr-x  1 root root        2688 Oct 31  2018 dvipdft
# -rwxr-xr-x  1 root root      204944 Oct 31  2018 dvips
# lrwxrwxrwx  1 root root          53 Feb 10 18:08 dvired -> /usr/share/texlive/texmf-dist/scripts/tetex/dvired.sh
# -rwxr-xr-x  1 root root     3178136 Feb  5 00:35 dwp
# -rwxr-xr-x  1 root root      166504 Jun 10  2014 dwz
# -rwxr-xr-x  1 root root         234 Oct 15  2017 easy_install
# -rwxr-xr-x  1 root root         234 Oct 15  2017 easy_install-2.7
# lrwxrwxrwx  1 root root           8 Feb 10 18:07 ebb -> dvipdfmx
# -rwxr-xr-x  1 root root       33088 Aug 20  2019 echo
# lrwxrwxrwx  1 root root          40 Feb 20 10:45 ecm-python-wrap -> /var/lib/ecm-agent/lib/python/bin/python
# -rwxr-xr-x  1 root root       49848 Jun 10  2014 ed
# -rwxr-xr-x. 1 root root         290 Aug  3  2017 egrep
# -rwxr-xr-x  1 root root       49984 Dec  3 01:46 eject
# -rwxr-xr-x  1 root root       32952 Feb  5 00:35 elfedit
# lrwxrwxrwx  1 root root          38 Jul 10  2018 emr-agent -> /usr/local/emr/emr-agent/bin/emr-agent
# lrwxrwxrwx  1 root root          44 Nov  2  2017 emr-watchdog -> /usr/local/emr/emr-watchdog/bin/emr-watchdog
# -rwxr-xr-x  1 root root       29008 Aug 20  2019 env
# -rwxr-xr-x. 1 root root       36872 Aug  3  2017 envsubst
# -rwxr-xr-x  1 root root         639 Dec  3 01:54 eps2eps
# -rwxr-xr-x. 1 root root      147880 Jun 10  2014 eqn
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 etex -> pdftex
# lrwxrwxrwx  1 root root           2 Feb 10 17:59 ex -> vi
# -rwxr-xr-x  1 root root       33264 Aug 20  2019 expand
# -rwxr-xr-x  1 root root       11352 Jun 24  2015 expect
# -rwxr-xr-x  1 root root       37408 Aug 20  2019 expr
# lrwxrwxrwx  1 root root          26 Feb 10 18:00 extcheck -> /etc/alternatives/extcheck
# lrwxrwxrwx  1 root root           8 Feb 10 18:07 extractbb -> dvipdfmx
# lrwxrwxrwx  1 root root           8 Feb 10 18:07 f95 -> gfortran
# -rwxr-xr-x  1 root root       95528 Aug 20  2019 factor
# -rwxr-xr-x  1 root root       28512 Dec  3 01:46 fallocate
# -rwxr-xr-x  1 root root       28928 Aug 20  2019 false
# -rwxr-xr-x  1 root root          26 Aug  8  2019 fc
# -rwxr-xr-x  1 root root         132 Oct 30  2018 fc-cache
# -rwxr-xr-x  1 root root       15824 Oct 31  2018 fc-cache-64
# -rwxr-xr-x  1 root root       15768 Oct 31  2018 fc-cat
# -rwxr-xr-x  1 root root       11464 Oct 31  2018 fc-conflist
# -rwxr-xr-x  1 root root       11528 Oct 31  2018 fc-list
# -rwxr-xr-x  1 root root       11592 Oct 31  2018 fc-match
# -rwxr-xr-x  1 root root       11528 Oct 31  2018 fc-pattern
# -rwxr-xr-x  1 root root       11496 Oct 31  2018 fc-query
# -rwxr-xr-x  1 root root       11536 Oct 31  2018 fc-scan
# -rwxr-xr-x  1 root root       11536 Oct 31  2018 fc-validate
# -rwxr-xr-x  1 root root          26 Aug  8  2019 fg
# -rwxr-xr-x  1 root root       11504 Oct 31  2018 fgconsole
# -rwxr-xr-x. 1 root root         290 Aug  3  2017 fgrep
# -rwxr-xr-x  1 root root       19848 Oct 31  2018 file
# -rwxr-xr-x  1 root root      199304 Oct 31  2018 find
# -rwxr-xr-x  1 root root       23614 Jan 22  2019 find2perl
# -rwxr-xr-x  1 root root         748 Nov 21  2015 find-jar
# -rwxr-xr-x  1 root root       59768 Dec  3 01:46 findmnt
# -rwxr-xr-x  1 root root        4371 Aug  9  2019 find-repos-of-install
# -rwxr-xr-x. 1 root root       15736 Aug  2  2017 fipscheck
# -rwxr-xr-x. 1 root root       11576 Aug  2  2017 fipshmac
# -rwxr-xr-x  1 root root      116196 Feb  5 00:29 firewall-cmd
# -rwxr-xr-x  1 root root      103607 Feb  5 00:29 firewall-offline-cmd
# -rwxr-xr-x  1 root root         212 Apr 23  2018 flask
# -rwxr-xr-x  1 root root       24448 Dec  3 01:46 flock
# -rwxr-xr-x  1 root root       37360 Aug 20  2019 fmt
# lrwxrwxrwx  1 root root          49 Feb 10 18:08 fmtutil -> /usr/share/texlive/texmf/scripts/tetex/fmtutil.sh
# lrwxrwxrwx  1 root root          53 Feb 10 18:08 fmtutil-sys -> /usr/share/texlive/texmf/scripts/tetex/fmtutil-sys.sh
# -rwxr-xr-x  1 root root       37336 Aug 20  2019 fold
# -rwxr-xr-x  1 root root       36856 Oct 31  2018 fonttosfnt
# -rwxr-xr-x  1 root root       19792 Oct 19 00:08 free
# -rwxr-xr-x  1 root root        4491 Aug  9  2019 freetype-config
# -rwxr-xr-x  1 root root       16480 Dec 23 23:39 fribidi
# -rwxr-xr-x  1 root root         683 Jun 24  2015 ftp-rfc
# -rwxr-xr-x  1 root root       32136 Aug  9  2019 funzip
# -rwsr-xr-x  1 root root       32096 Oct 31  2018 fusermount
# -rwxr-xr-x  4 root root      772744 Aug  7  2019 g++
# -rwxr-xr-x  1 root root       19944 Aug  9  2019 gapplication
# -rwxr-xr-x. 1 root root      428584 Jun 29  2017 gawk
# -rwxr-xr-x  2 root root      768648 Aug  7  2019 gcc
# -rwxr-xr-x  1 root root       27136 Aug  7  2019 gcc-ar
# -rwxr-xr-x  1 root root       27136 Aug  7  2019 gcc-nm
# -rwxr-xr-x  1 root root       27144 Aug  7  2019 gcc-ranlib
# -rwxr-xr-x  1 root root      314904 Aug  7  2019 gcov
# -rwxr-xr-x  1 root root       41136 Aug  9  2019 gdbus
# -rwxr-xr-x  1 root root       15752 Oct 31  2018 gdk-pixbuf-query-loaders-64
# -rwxr-xr-x  1 root root       15968 Oct 31  2018 gdk-pixbuf-thumbnailer
# -rwxr-xr-x  1 root root       23136 Aug  7  2019 gencat
# -rwxr-xr-x. 2 root root       11544 Aug  4  2017 genl-ctrl-list
# -rwxr-xr-x  1 root root       15648 Aug  9  2019 geoiplookup
# -rwxr-xr-x  1 root root       11424 Aug  9  2019 geoiplookup6
# -rwxr-xr-x  1 root root       32072 Aug 13  2019 geoipupdate
# lrwxrwxrwx. 1 root root           3 Oct 15  2017 geqn -> eqn
# -rwxr-xr-x  1 root root       22920 Aug  7  2019 getconf
# -rwxr-xr-x  1 root root       27896 Aug  7  2019 getent
# -rwxr-xr-x  1 root root       24872 Apr 11  2018 getfacl
# -rwxr-xr-x  1 root root       11496 Oct 31  2018 getkeycodes
# -rwxr-xr-x  1 root root       15752 Dec  3 01:46 getopt
# -rwxr-xr-x  1 root root          31 Aug  8  2019 getopts
# -rwxr-xr-x. 1 root root       36800 Aug  3  2017 gettext
# -rwxr-xr-x. 1 root root        4629 Aug  3  2017 gettext.sh
# -rwxr-xr-x  1 root root      772728 Aug  7  2019 gfortran
# -rwxr-xr-x  1 root root       45088 Oct 31  2018 gftodvi
# -rwxr-xr-x  1 root root       28368 Oct 31  2018 gftopk
# -rwxr-xr-x  1 root root       28296 Oct 31  2018 gftype
# lrwxrwxrwx  1 root root          11 Feb 10 18:08 ghostscript -> /usr/bin/gs
# -rwxr-xr-x  1 root root       75176 Aug  9  2019 gio
# -rwxr-xr-x  1 root root       11592 Aug  9  2019 gio-querymodules-64
# -rwxr-xr-x  3 root root     2242320 Dec 26 03:53 git
# -rwxr-xr-x  3 root root     2242320 Dec 26 03:53 git-receive-pack
# -rwxr-xr-x  1 root root     1189752 Dec 26 03:53 git-shell
# -rwxr-xr-x  3 root root     2242320 Dec 26 03:53 git-upload-archive
# -rwxr-xr-x  1 root root     1278136 Dec 26 03:53 git-upload-pack
# -rwxr-xr-x  1 root root       45440 Aug  9  2019 glib-compile-schemas
# lrwxrwxrwx  1 root root           4 Feb 10 17:59 gmake -> make
# -rwxr-xr-x  1 root root       20672 Oct 13  2015 gmetric
# lrwxrwxrwx. 1 root root           4 Oct 15  2017 gneqn -> neqn
# lrwxrwxrwx. 1 root root           5 Oct 15  2017 gnroff -> nroff
# -rwsr-xr-x  1 root root       78408 Aug  9  2019 gpasswd
# lrwxrwxrwx  1 root root           4 Jan 14 10:54 gpg -> gpg2
# -rwxr-xr-x  1 root root      749976 Jul 13  2018 gpg2
# -rwxr-xr-x  1 root root      296696 Jul 13  2018 gpg-agent
# -rwxr-xr-x  1 root root      143680 Jul 13  2018 gpgconf
# -rwxr-xr-x  1 root root      156352 Jul 13  2018 gpg-connect-agent
# -rwxr-xr-x. 1 root root       23736 Jun 10  2014 gpg-error
# -rwxr-xr-x  1 root root       24272 Jul 13  2018 gpgparsemail
# -rwxr-xr-x  1 root root       50056 Jul 13  2018 gpgsplit
# lrwxrwxrwx  1 root root           5 Jan 14 10:54 gpgv -> gpgv2
# -rwxr-xr-x  1 root root      353672 Jul 13  2018 gpgv2
# -rwxr-xr-x  1 root root        3307 Jul 13  2018 gpg-zip
# lrwxrwxrwx. 1 root root           3 Oct 15  2017 gpic -> pic
# -rwxr-xr-x  1 root root      100776 Feb  5 00:35 gprof
# -rwxr-xr-x  1 root root       24224 Jul 21  2017 gr2fonttest
# -rwxr-xr-x. 1 root root      159024 Aug  3  2017 grep
# -rwxr-xr-x. 1 root root       83584 Jun 10  2014 groff
# -rwxr-xr-x. 1 root root      144232 Jun 10  2014 grops
# -rwxr-xr-x. 1 root root      100952 Jun 10  2014 grotty
# -rwxr-xr-x  1 root root       33192 Aug 20  2019 groups
# -rwxr-xr-x  1 root root       22513 Jan  6 13:23 growpart
# -rwxr-xr-x  1 root root      401448 Aug  8  2019 grub2-editenv
# -rwxr-xr-x  1 root root      833888 Aug  8  2019 grub2-file
# -rwxr-xr-x  1 root root     1062640 Aug  8  2019 grub2-fstest
# -rwxr-xr-x  1 root root      260920 Aug  8  2019 grub2-glue-efi
# -rwxr-xr-x  1 root root        1668 Aug  8  2019 grub2-kbdcomp
# -rwxr-xr-x  1 root root      243520 Aug  8  2019 grub2-menulst2cfg
# -rwxr-xr-x  1 root root      290400 Aug  8  2019 grub2-mkfont
# -rwxr-xr-x  1 root root      384136 Aug  8  2019 grub2-mkimage
# -rwxr-xr-x  1 root root      267120 Aug  8  2019 grub2-mklayout
# -rwxr-xr-x  1 root root      435960 Aug  8  2019 grub2-mknetdir
# -rwxr-xr-x  1 root root      273720 Aug  8  2019 grub2-mkpasswd-pbkdf2
# -rwxr-xr-x  1 root root      260568 Aug  8  2019 grub2-mkrelpath
# -rwxr-xr-x  1 root root     1025760 Aug  8  2019 grub2-mkrescue
# -rwxr-xr-x  1 root root      538880 Aug  8  2019 grub2-mkstandalone
# -rwxr-xr-x  1 root root      842904 Aug  8  2019 grub2-render-label
# -rwxr-xr-x  1 root root      298368 Aug  8  2019 grub2-script-check
# -rwxr-xr-x  1 root root      769672 Aug  8  2019 grub2-syslinux2cfg
# -rwxr-xr-x  1 root root       11232 Dec  3 01:54 gs
# -rwxr-xr-x  1 root root         350 Dec  3 01:54 gsbj
# -rwxr-xr-x  1 root root         352 Dec  3 01:54 gsdj
# -rwxr-xr-x  1 root root         352 Dec  3 01:54 gsdj500
# -rwxr-xr-x  1 root root       24376 Aug  9  2019 gsettings
# -rwxr-xr-x  1 root root       28632 Oct 31  2018 gsftopk
# -rwxr-xr-x  1 root root         353 Dec  3 01:54 gslj
# -rwxr-xr-x  1 root root         350 Dec  3 01:54 gslp
# -rwxr-xr-x  1 root root         277 Dec  3 01:54 gsnd
# lrwxrwxrwx. 1 root root           6 Oct 15  2017 gsoelim -> soelim
# -rwxr-xr-x  1 root root       23728 Sep 14 02:05 gss-client
# -rwxr-xr-x  1 root root       20360 Oct 13  2015 gstat
# lrwxrwxrwx  1 root root           3 Feb 10 17:59 gtar -> tar
# lrwxrwxrwx. 1 root root           3 Oct 15  2017 gtbl -> tbl
# -rwxr-xr-x  1 root root       15656 Aug  2  2017 gtk-query-immodules-2.0-64
# -rwxr-xr-x  1 root root       33296 Oct 31  2018 gtk-update-icon-cache
# lrwxrwxrwx. 1 root root           5 Oct 15  2017 gtroff -> troff
# -rwxr-xr-x  1 root root        2253 Apr 11  2018 gunzip
# -rwxr-xr-x  1 root root        5931 Apr 11  2018 gzexe
# -rwxr-xr-x  1 root root      100800 Apr 11  2018 gzip
# -rwxr-xr-x  1 root root       28310 Jan 22  2019 h2ph
# -rwxr-xr-x  1 root root       36728 Aug  9  2019 halog
# -rwxr-xr-x. 1 root root       11448 Nov  6  2016 hdsploader
# -rwxr-xr-x  1 root root       41472 Aug 20  2019 head
# -rwxr-xr-x  1 root root       32784 Dec  3 01:46 hexdump
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 hostid
# -rwxr-xr-x  1 root root       15784 Oct 19 00:02 hostname
# -rwxr-xr-x  1 root root      325712 Feb  5 00:30 hostnamectl
# -rwxr-xr-x  1 root root       23736 Aug  8  2019 htdbm
# -rwxr-xr-x  1 root root       15520 Aug  8  2019 htdigest
# -rwxr-xr-x  1 root root      169624 Jan 17  2019 htop
# -rwxr-xr-x  1 root root       19640 Aug  8  2019 htpasswd
# -rwxr-xr-x  1 root root       11336 Aug  8  2019 httxt2dbm
# lrwxrwxrwx  1 root root           7 Feb 10 17:59 i386 -> setarch
# -rwxr-xr-x  1 root root       32496 Aug 12  2017 iceauth
# -rwxr-xr-x  1 root root       60376 Aug  7  2019 iconv
# -rwxr-xr-x  1 root root         172 Aug  6  2019 icu-config
# -rwxr-xr-x  1 root root       22004 Aug  9  2019 icu-config-64
# -rwxr-xr-x  1 root root       15976 Aug  9  2019 icuinfo
# -rwxr-xr-x  1 root root       37400 Aug 20  2019 id
# -rwxr-xr-x. 1 root root       11608 Aug  4  2017 idiag-socket-details
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 idlj -> /etc/alternatives/idlj
# -rwxr-xr-x. 1 root root       33232 Nov 22  2015 idn
# -rwxr-xr-x. 1 root root        3188 Jun 29  2017 igawk
# -rwxr-xr-x  1 root root      271552 Apr 11  2018 info
# -rwxr-xr-x  1 root root       57416 Sep  7  2017 infocmp
# -rwxr-xr-x  1 root root       21984 Apr 11  2018 infokey
# lrwxrwxrwx  1 root root           3 Oct 15  2017 infotocap -> tic
# lrwxrwxrwx  1 root root           2 Feb 10 18:08 inimf -> mf
# lrwxrwxrwx  1 root root           3 Feb 10 18:08 initex -> tex
# -rwxr-xr-x  1 root root       11384 Aug  8  2019 innochecksum
# -rwxr-xr-x  1 root root      142944 Aug 20  2019 install
# -rwxr-xr-x  1 root root       24432 Dec  3 01:46 ionice
# -rwxr-xr-x  1 root root       62232 Aug  9  2019 iostat
# -rwxr-xr-x  1 root root       15416 Aug  9  2019 ipcalc
# -rwxr-xr-x  1 root root       24584 Dec  3 01:46 ipcmk
# -rwxr-xr-x  1 root root       28520 Dec  3 01:46 ipcrm
# -rwxr-xr-x  1 root root       49520 Dec  3 01:46 ipcs
# -rwxr-xr-x  1 root root       10384 Aug  9  2019 iprange
# lrwxrwxrwx  1 root root          23 Feb 10 17:58 iptables-xml -> /usr/sbin/xtables-multi
# -rwxr-xr-x  1 root root       24400 Dec  3 01:46 isosize
# lrwxrwxrwx  1 root root          21 Feb 10 18:00 jar -> /etc/alternatives/jar
# lrwxrwxrwx  1 root root          27 Feb 10 18:00 jarsigner -> /etc/alternatives/jarsigner
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 java -> /etc/alternatives/java
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 javac -> /etc/alternatives/javac
# lrwxrwxrwx  1 root root          25 Feb 10 18:00 javadoc -> /etc/alternatives/javadoc
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 javah -> /etc/alternatives/javah
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 javap -> /etc/alternatives/javap
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 jcmd -> /etc/alternatives/jcmd
# lrwxrwxrwx  1 root root          26 Feb 10 18:00 jconsole -> /etc/alternatives/jconsole
# lrwxrwxrwx  1 root root          21 Feb 10 18:00 jdb -> /etc/alternatives/jdb
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 jdeps -> /etc/alternatives/jdeps
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 jhat -> /etc/alternatives/jhat
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 jinfo -> /etc/alternatives/jinfo
# lrwxrwxrwx  1 root root          21 Feb 10 18:00 jjs -> /etc/alternatives/jjs
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 jmap -> /etc/alternatives/jmap
# -rwxr-xr-x  1 root root          28 Aug  8  2019 jobs
# -rwxr-xr-x  1 root root       49920 Aug 20  2019 join
# -rwxr-xr-x  1 root root      550752 Feb  5 00:30 journalctl
# lrwxrwxrwx  1 root root          21 Feb 10 18:00 jps -> /etc/alternatives/jps
# lrwxrwxrwx  1 root root          28 Feb 10 18:00 jrunscript -> /etc/alternatives/jrunscript
# lrwxrwxrwx  1 root root          27 Feb 10 18:00 jsadebugd -> /etc/alternatives/jsadebugd
# -rwxr-xr-x  1 root root        1018 Oct 15  2017 jsondiff
# -rwxr-xr-x  1 root root        3661 Oct 15  2017 jsonpatch
# -rwxr-xr-x  1 root root        1341 Oct 15  2017 jsonpointer
# lrwxrwxrwx  1 root root          24 Feb 10 18:00 jstack -> /etc/alternatives/jstack
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 jstat -> /etc/alternatives/jstat
# lrwxrwxrwx  1 root root          24 Feb 10 18:00 jstatd -> /etc/alternatives/jstatd
# -rwxr-xr-x  1 root root        1737 Nov 21  2015 jvmjar
# -rwxr-xr-x  1 root root        2004 Sep 14 02:05 k5srvutil
# -rwxr-xr-x  1 root root       77464 Sep 14 02:05 kadmin
# -rwxr-xr-x  1 root root       11528 Oct 31  2018 kbdinfo
# -rwxr-xr-x  1 root root       11504 Oct 31  2018 kbd_mode
# -rwxr-xr-x  1 root root       11560 Oct 31  2018 kbdrate
# -rwxr-xr-x  1 root root       11232 Sep 14 02:05 kdestroy
# -rwxr-xr-x  1 root root       32623 Aug  8  2019 kdumpctl
# -rwxr-xr-x  1 root root        4811 Feb  5 00:29 kernel-install
# lrwxrwxrwx  1 root root          25 Feb 10 18:00 keytool -> /etc/alternatives/keytool
# -rwxr-xr-x  1 root root       10886 Jun 24  2015 kibitz
# -rwxr-xr-x  1 root root       33608 Dec  3 01:46 kill
# -rwxr-xr-x  1 root root       24720 Aug  9  2019 killall
# -rwxr-xr-x  1 root root       27672 Sep 14 02:05 kinit
# -rwxr-xr-x  1 root root       27832 Sep 14 02:05 klist
# -rwxr-xr-x  1 root root      146688 Aug  9  2019 kmod
# -rwxr-xr-x  1 root root       11216 Sep 14 02:05 kpasswd
# -rwxr-xr-x  1 root root        7264 Oct 31  2018 kpseaccess
# lrwxrwxrwx  1 root root           8 Feb 10 18:08 kpsepath -> kpsetool
# -rwxr-xr-x  1 root root        7272 Oct 31  2018 kpsereadlink
# -rwxr-xr-x  1 root root       11376 Oct 31  2018 kpsestat
# lrwxrwxrwx  1 root root          55 Feb 10 18:08 kpsetool -> /usr/share/texlive/texmf-dist/scripts/tetex/kpsetool.sh
# lrwxrwxrwx  1 root root          56 Feb 10 18:08 kpsewhere -> /usr/share/texlive/texmf-dist/scripts/tetex/kpsewhere.sh
# -rwxr-xr-x  1 root root       20744 Oct 31  2018 kpsewhich
# lrwxrwxrwx  1 root root           8 Feb 10 18:08 kpsexpand -> kpsetool
# -rwxr-xr-x  1 root root        7123 Sep 14 02:05 krb5-config
# -rwsr-xr-x  1 root root       61320 Sep 14 02:05 ksu
# -rwxr-xr-x  1 root root       11224 Sep 14 02:05 kswitch
# -rwxr-xr-x  1 root root       23688 Sep 14 02:05 ktutil
# -rwxr-xr-x  1 root root       15360 Sep 14 02:05 kvno
# -rwxr-xr-x. 1 root root       19568 Jun 10  2014 last
# lrwxrwxrwx. 1 root root           4 Oct 15  2017 lastb -> last
# -rwxr-xr-x  1 root root       19608 Aug  9  2019 lastlog
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 latex -> pdftex
# -rwxr-xr-x  1 root root       15896 Apr 13  2018 lchfn
# -rwxr-xr-x  1 root root       15864 Apr 13  2018 lchsh
# lrwxrwxrwx  1 root root          20 Feb 10 17:58 ld -> /etc/alternatives/ld
# lrwxrwxrwx  1 root root          10 Feb 10 17:59 ldapadd -> ldapmodify
# -rwxr-xr-x  1 root root       61256 Jan 30  2019 ldapcompare
# -rwxr-xr-x  1 root root       65416 Jan 30  2019 ldapdelete
# -rwxr-xr-x  1 root root       61248 Jan 30  2019 ldapexop
# -rwxr-xr-x  1 root root       73576 Jan 30  2019 ldapmodify
# -rwxr-xr-x  1 root root       61264 Jan 30  2019 ldapmodrdn
# -rwxr-xr-x  1 root root       65344 Jan 30  2019 ldappasswd
# -rwxr-xr-x  1 root root       85928 Jan 30  2019 ldapsearch
# -rwxr-xr-x  1 root root       19728 Jan 30  2019 ldapurl
# -rwxr-xr-x  1 root root       61264 Jan 30  2019 ldapwhoami
# -rwxr-xr-x  1 root root     1006216 Feb  5 00:35 ld.bfd
# -rwxr-xr-x  1 root root        5302 Aug  7  2019 ldd
# -rwxr-xr-x  1 root root     5354120 Feb  5 00:35 ld.gold
# -rwxr-xr-x. 1 root root      158240 Jul 31  2015 less
# -rwxr-xr-x. 1 root root       11376 Jul 31  2015 lessecho
# -rwxr-xr-x. 1 root root       17056 Jul 31  2015 lesskey
# -rwxr-xr-x. 1 root root        2291 Jul 31  2015 lesspipe.sh
# -rwxr-xr-x  1 root root       87128 Oct 31  2018 lexgrog
# -rwxr-xr-x  1 root root        2437 Dec 10  2015 libpng15-config
# lrwxrwxrwx  1 root root          15 Feb 10 18:08 libpng-config -> libpng15-config
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 link
# lrwxrwxrwx  1 root root           7 Feb 10 17:59 linux32 -> setarch
# lrwxrwxrwx  1 root root           7 Feb 10 17:59 linux64 -> setarch
# -rwxr-xr-x. 1 root root        5995 Nov  6  2016 linux-boot-prober
# -rwxr-xr-x  1 root root       58592 Aug 20  2019 ln
# -rwxr-xr-x  1 root root      113184 Oct 31  2018 loadkeys
# -rwxr-xr-x  1 root root       24544 Oct 31  2018 loadunimap
# -rwxr-xr-x  1 root root       38720 Aug  7  2019 locale
# -rwxr-xr-x  1 root root      334016 Feb  5 00:30 localectl
# -rwxr-xr-x  1 root root      322928 Aug  7  2019 localedef
# -rwx--s--x  1 root slocate    40520 Apr 11  2018 locate
# -rwxr-xr-x  1 root root       29312 Dec  3 01:46 logger
# -rwxr-xr-x  1 root root       37248 Dec  3 01:46 login
# -rwxr-xr-x  1 root root      501344 Feb  5 00:30 loginctl
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 logname
# -rwxr-xr-x  1 root root       11344 Aug  8  2019 logresolve
# -rwxr-xr-x  1 root root       11544 Dec  3 01:46 look
# lrwxrwxrwx  1 root root          26 Feb 10 17:59 lp -> /etc/alternatives/print-lp
# -rwxr-xr-x  1 root root       19528 Aug  9  2019 lp.cups
# -rwxr-xr-x  1 root root       15440 Aug  9  2019 lpoptions
# -rwxr-xr-x  1 root root       15416 Aug  9  2019 lppasswd
# lrwxrwxrwx  1 root root          27 Feb 10 17:59 lpq -> /etc/alternatives/print-lpq
# -rwxr-xr-x  1 root root       19568 Aug  9  2019 lpq.cups
# lrwxrwxrwx  1 root root          23 Feb 10 17:59 lpr -> /etc/alternatives/print
# -rwxr-xr-x  1 root root       15400 Aug  9  2019 lpr.cups
# lrwxrwxrwx  1 root root          28 Feb 10 17:59 lprm -> /etc/alternatives/print-lprm
# -rwxr-xr-x  1 root root       11296 Aug  9  2019 lprm.cups
# -rwxr-xr-x  1 root root        5470 Dec  3 01:54 lprsetup.sh
# lrwxrwxrwx  1 root root          30 Feb 10 17:59 lpstat -> /etc/alternatives/print-lpstat
# -rwxr-xr-x  1 root root       32232 Aug  9  2019 lpstat.cups
# -rwxr-xr-x  1 root root        2619 Jun 24  2015 lpunlock
# -rwxr-xr-x  1 root root      117608 Aug 20  2019 ls
# -rwxr-xr-x  1 root root     2356616 Jun 10  2016 lsar
# -rwxr-xr-x  1 root root       11600 Aug  9  2019 lsattr
# -rwxr-xr-x  1 root root       81072 Dec  3 01:46 lsblk
# -rwxr-xr-x  1 root root       15929 Mar 27  2015 lsb_release
# -rwxr-xr-x  1 root root       62208 Dec  3 01:46 lscpu
# -rwxr-xr-x  1 root root        6410 Aug  9  2019 lsinitrd
# -rwxr-xr-x  1 root root       62408 Dec  3 01:46 lsipc
# -rwxr-xr-x  1 root root       42000 Dec  3 01:46 lslocks
# -rwxr-xr-x  1 root root       54152 Dec  3 01:46 lslogins
# -rwxr-xr-x  1 root root       41760 Dec  3 01:46 lsmem
# -rwxr-xr-x  1 root root       37304 Dec  3 01:46 lsns
# -rwxr-xr-x. 1 root root       57832 Aug  3  2017 lsscsi
# -rwxr-xr-x. 1 root root       15840 Nov  6  2016 lua
# -rwxr-xr-x. 1 root root      121888 Nov  6  2016 luac
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 lualatex -> luatex
# -rwxr-xr-x  1 root root     6079960 Oct 31  2018 luatex
# -rwxr-xr-x  1 root root      124344 Aug  9  2019 lz4
# -rwxr-xr-x  1 root root      124344 Aug  9  2019 lz4c
# lrwxrwxrwx  1 root root           3 Jan 14 09:55 lz4cat -> lz4
# -rwxr-xr-x  1 root root      154800 Nov 20  2015 m4
# -rwxr-xr-x  1 root root      546704 Feb  5 00:30 machinectl
# lrwxrwxrwx  1 root root           5 Feb 10 18:00 mail -> mailx
# lrwxrwxrwx  1 root root          15 Feb 10 18:00 Mail -> ../../bin/mailx
# lrwxrwxrwx  1 root root          27 Feb 10 17:59 mailq -> /etc/alternatives/mta-mailq
# lrwxrwxrwx  1 root root          31 Feb 10 17:59 mailq.postfix -> ../../usr/sbin/sendmail.postfix
# -rwxr-xr-x  1 root root      392880 Apr 11  2018 mailx
# -rwxr-xr-x  1 root root      182752 Aug  9  2019 make
# -rwxr-xr-x  1 root root       19072 Aug  7  2019 makedb
# -rwxr-xr-x  1 root root       79912 Oct 31  2018 makeindex
# lrwxrwxrwx  1 root root           8 Feb 10 18:08 makeinfo -> texi2any
# -rwxr-xr-x  1 root root      102848 Oct 31  2018 man
# -rwxr-xr-x  1 root root      125184 Oct 31  2018 mandb
# -rwxr-xr-x  1 root root       33336 Oct 31  2018 manpath
# -rwxr-xr-x  1 root root       20344 Oct 31  2018 mapscrn
# -rwxr-xr-x  1 root root        1014 Oct 15  2017 markdown_py
# -rwxr-xr-x  1 root root       15808 Dec  3 01:46 mcookie
# -rwxr-xr-x  1 root root       41504 Aug 20  2019 md5sum
# -rwxr-xr-x  1 root root       66936 Jul 27  2015 memaslap
# -rwxr-xr-x  1 root root       59096 Jul 27  2015 memcapable
# -rwxr-xr-x  1 root root       20472 Jul 27  2015 memcat
# -rwxr-xr-x  1 root root       20672 Jul 27  2015 memcp
# -rwxr-xr-x  1 root root       16192 Jul 27  2015 memdump
# -rwxr-xr-x  1 root root       15832 Jul 27  2015 memerror
# -rwxr-xr-x  1 root root       16096 Jul 27  2015 memexist
# -rwxr-xr-x  1 root root       16112 Jul 27  2015 memflush
# -rwxr-xr-x  1 root root       11328 Jul 27  2015 memparse
# -rwxr-xr-x  1 root root       16216 Jul 27  2015 memping
# -rwxr-xr-x  1 root root       16160 Jul 27  2015 memrm
# -rwxr-xr-x  1 root root       25144 Jul 27  2015 memslap
# -rwxr-xr-x  1 root root       20656 Jul 27  2015 memstat
# -rwxr-xr-x  1 root root       16184 Jul 27  2015 memtouch
# -rwxr-xr-x. 1 root root       11240 Jun 10  2014 mesg
# -rwxr-xr-x  1 root root      292600 Oct 31  2018 mf
# -rwxr-xr-x  1 root root      287848 Oct 31  2018 mf-nowin
# -rwxr-xr-x  1 root root       53024 Oct 31  2018 mft
# -rwxr-xr-x. 1 root root       15744 Nov  6  2016 mixartloader
# -rwxr-xr-x  1 root root       79768 Aug 20  2019 mkdir
# -rwxr-xr-x  1 root root       63056 Aug 20  2019 mkfifo
# -rwxr-xr-x  1 root root          65 Oct 31  2018 mkfontdir
# -rwxr-xr-x  1 root root       33256 Oct 31  2018 mkfontscale
# -rwxr-xr-x  1 root root         947 Oct 31  2018 mkindex
# -rwxr-xr-x  1 root root        3013 Aug  9  2019 mkinitrd
# lrwxrwxrwx  1 root root          67 Feb 10 18:07 mkluatexfontdb -> /usr/share/texlive/texmf-dist/scripts/luaotfload/mkluatexfontdb.lua
# -rwxr-xr-x  1 root root       67184 Aug 20  2019 mknod
# -rwxr-xr-x  1 root root         171 Oct 31  2018 mkocp
# -rwxr-xr-x  1 root root          85 Oct 31  2018 mkofm
# -rwxr-xr-x  1 root root        5691 Jun 24  2015 mkpasswd
# -rwxr-xr-x  1 root root       41632 Aug 20  2019 mktemp
# lrwxrwxrwx  1 root root           7 Feb 10 18:07 mktexfmt -> fmtutil
# -rwxr-xr-x  1 root root        7564 Oct 31  2018 mktexlsr
# -rwxr-xr-x  1 root root        3814 Oct 31  2018 mktexmf
# -rwxr-xr-x  1 root root        9736 Oct 31  2018 mktexpk
# -rwxr-xr-x  1 root root        4856 Oct 31  2018 mktextfm
# -rwxr-xr-x  1 root root      161480 Dec 11 04:48 modutil
# -rwxr-xr-x  1 root root       41112 Dec  3 01:46 more
# -rwsr-xr-x  1 root root       44264 Dec  3 01:46 mount
# -rwxr-xr-x  1 root root       15688 Dec  3 01:46 mountpoint
# -rwxr-xr-x  1 root root       53792 Aug  9  2019 mpstat
# lrwxrwxrwx  1 root root          61 Feb 10 18:08 mptopdf -> /usr/share/texlive/texmf-dist/scripts/context/perl/mptopdf.pl
# -rwxr-xr-x. 1 root root       23920 Aug  3  2017 msgattrib
# -rwxr-xr-x. 1 root root       23880 Aug  3  2017 msgcat
# -rwxr-xr-x. 1 root root       24144 Aug  3  2017 msgcmp
# -rwxr-xr-x. 1 root root       23872 Aug  3  2017 msgcomm
# -rwxr-xr-x. 1 root root       19760 Aug  3  2017 msgconv
# -rwxr-xr-x. 1 root root       19752 Aug  3  2017 msgen
# -rwxr-xr-x. 1 root root       15696 Aug  3  2017 msgexec
# -rwxr-xr-x. 1 root root       28224 Aug  3  2017 msgfilter
# -rwxr-xr-x. 1 root root       78984 Aug  3  2017 msgfmt
# -rwxr-xr-x. 1 root root       36816 Aug  3  2017 msggrep
# -rwxr-xr-x. 1 root root       12751 Mar 15  2017 msghack
# -rwxr-xr-x. 1 root root       45440 Aug  3  2017 msginit
# -rwxr-xr-x. 1 root root       53848 Aug  3  2017 msgmerge
# -rwxr-xr-x. 1 root root       32448 Aug  3  2017 msgunfmt
# -rwxr-xr-x. 1 root root       19776 Aug  3  2017 msguniq
# -rwxr-xr-x  1 root root        1446 Aug  8  2019 msql2mysql
# -rwxr-xr-x  1 root root      130360 Aug 20  2019 mv
# -rwxr-xr-x  1 root root     3422080 Aug  8  2019 myisamchk
# -rwxr-xr-x  1 root root     3297968 Aug  8  2019 myisam_ftdump
# -rwxr-xr-x  1 root root     3280120 Aug  8  2019 myisamlog
# -rwxr-xr-x  1 root root     3323192 Aug  8  2019 myisampack
# -rwxr-xr-x  1 root root     2918024 Aug  8  2019 my_print_defaults
# -rwxr-xr-x  1 root root     3539560 Aug  8  2019 mysql
# -rwxr-xr-x  1 root root      111971 Aug  8  2019 mysqlaccess
# -rwxr-xr-x  1 root root     3096672 Aug  8  2019 mysqladmin
# -rwxr-xr-x  1 root root     3259992 Aug  8  2019 mysqlbinlog
# lrwxrwxrwx  1 root root          26 Jan 14 14:59 mysqlbug -> /etc/alternatives/mysqlbug
# -rwxr-xr-x  1 root root     3094152 Aug  8  2019 mysqlcheck
# lrwxrwxrwx  1 root root          30 Jan 14 14:59 mysql_config -> /etc/alternatives/mysql_config
# -rwxr-xr-x  1 root root        4215 Aug  8  2019 mysql_convert_table_format
# -rwxr-xr-x  1 root root       24116 Aug  8  2019 mysqld_multi
# -rwxr-xr-x  1 root root       26991 Aug  8  2019 mysqld_safe
# -rwxr-xr-x  1 root root     2887224 Aug  8  2019 mysqld_safe_helper
# -rwxr-xr-x  1 root root     3176784 Aug  8  2019 mysqldump
# -rwxr-xr-x  1 root root        7876 Aug  8  2019 mysqldumpslow
# -rwxr-xr-x  1 root root        3288 Aug  8  2019 mysql_find_rows
# -rwxr-xr-x  1 root root        1246 Aug  8  2019 mysql_fix_extensions
# -rwxr-xr-x  1 root root       34942 Aug  8  2019 mysqlhotcopy
# -rwxr-xr-x  1 root root     3089016 Aug  8  2019 mysqlimport
# -rwxr-xr-x  1 root root       17190 Aug  8  2019 mysql_install_db
# -rwxr-xr-x  1 root root     2926184 Aug  8  2019 mysql_plugin
# -rwxr-xr-x  1 root root       12126 Aug  8  2019 mysql_secure_installation
# -rwxr-xr-x  1 root root       17464 Aug  8  2019 mysql_setpermission
# -rwxr-xr-x  1 root root     3087552 Aug  8  2019 mysqlshow
# -rwxr-xr-x  1 root root     3106936 Aug  8  2019 mysqlslap
# -rwxr-xr-x  1 root root     3449056 Aug  8  2019 mysqltest
# -rwxr-xr-x  1 root root     2921504 Aug  8  2019 mysql_tzinfo_to_sql
# -rwxr-xr-x  1 root root     2998496 Aug  8  2019 mysql_upgrade
# -rwxr-xr-x  1 root root     2913088 Aug  8  2019 mysql_waitpid
# -rwxr-xr-x  1 root root        3856 Aug  8  2019 mysql_zap
# lrwxrwxrwx  1 root root          15 Feb 10 18:00 nail -> ../../bin/mailx
# -rwxr-xr-x  1 root root       28616 Dec  3 01:46 namei
# -rwxr-xr-x  1 root root      205904 Jun 10  2014 nano
# lrwxrwxrwx  1 root root          30 Feb 10 18:00 native2ascii -> /etc/alternatives/native2ascii
# -rwxr-xr-x  1 root root        5814 Sep  7  2017 ncurses5-config
# -rwxr-xr-x  1 root root        5817 Sep  7  2017 ncursesw5-config
# -rwxr-xr-x  1 root root       24192 Aug  9  2019 ndptool
# -rwxr-xr-x  1 root root        8347 Aug  9  2019 needs-restarting
# -rwxr-xr-x. 1 root root         271 Jun 10  2014 neqn
# -rwxr-xr-x  1 root root      155008 Aug  9  2019 netstat
# -rwxr-xr-x  1 root root       11592 Nov  6  2016 nettle-hash
# -rwxr-xr-x  1 root root        7208 Nov  6  2016 nettle-lfib-stream
# lrwxrwxrwx  1 root root          32 Feb 10 17:59 newaliases -> /etc/alternatives/mta-newaliases
# lrwxrwxrwx  1 root root          31 Feb 10 17:59 newaliases.postfix -> ../../usr/sbin/sendmail.postfix
# -rwxr-xr-x  1 root root       39000 Aug  9  2019 newgidmap
# -rwsr-xr-x  1 root root       41936 Aug  9  2019 newgrp
# -rwxr-xr-x  1 root root       38976 Aug  9  2019 newuidmap
# -rwxr-xr-x. 1 root root       12088 Aug  4  2017 nf-ct-add
# -rwxr-xr-x. 1 root root       16216 Aug  4  2017 nf-ct-list
# -rwxr-xr-x. 1 root root       16600 Aug  4  2017 nf-exp-add
# -rwxr-xr-x. 1 root root       16376 Aug  4  2017 nf-exp-delete
# -rwxr-xr-x. 1 root root       12088 Aug  4  2017 nf-exp-list
# -rwxr-xr-x. 1 root root       11504 Aug  4  2017 nf-log
# -rwxr-xr-x. 1 root root       11448 Aug  4  2017 nf-monitor
# -rwxr-xr-x. 1 root root       11544 Aug  4  2017 nf-queue
# -rwxr-xr-x  1 root root       53784 Aug  9  2019 nfsiostat-sysstat
# -rwxr-xr-x. 1 root root       36816 Aug  3  2017 ngettext
# -rwxr-xr-x  1 root root         560 Oct  3 13:12 nginx-upgrade
# -rwxr-xr-x  1 root root       33096 Aug 20  2019 nice
# lrwxrwxrwx  1 root root           8 Feb 10 17:59 nisdomainname -> hostname
# -rwxr-xr-x  1 root root       41576 Aug 20  2019 nl
# -rwxr-xr-x. 1 root root       11928 Aug  4  2017 nl-addr-add
# -rwxr-xr-x. 1 root root       12016 Aug  4  2017 nl-addr-delete
# -rwxr-xr-x. 1 root root       16256 Aug  4  2017 nl-addr-list
# -rwxr-xr-x. 2 root root       11976 Aug  4  2017 nl-class-add
# -rwxr-xr-x. 2 root root       11824 Aug  4  2017 nl-class-delete
# -rwxr-xr-x. 2 root root       11560 Aug  4  2017 nl-classid-lookup
# -rwxr-xr-x. 2 root root       11752 Aug  4  2017 nl-class-list
# -rwxr-xr-x. 2 root root       12040 Aug  4  2017 nl-cls-add
# -rwxr-xr-x. 2 root root       11960 Aug  4  2017 nl-cls-delete
# -rwxr-xr-x. 2 root root       11856 Aug  4  2017 nl-cls-list
# -rwxr-xr-x. 1 root root       11688 Aug  4  2017 nl-fib-lookup
# -rwxr-xr-x. 1 root root        7216 Aug  4  2017 nl-link-enslave
# -rwxr-xr-x. 1 root root        7232 Aug  4  2017 nl-link-ifindex2name
# -rwxr-xr-x. 2 root root       11800 Aug  4  2017 nl-link-list
# -rwxr-xr-x. 1 root root        7216 Aug  4  2017 nl-link-name2ifindex
# -rwxr-xr-x. 1 root root        7216 Aug  4  2017 nl-link-release
# -rwxr-xr-x. 1 root root       11920 Aug  4  2017 nl-link-set
# -rwxr-xr-x. 1 root root       11664 Aug  4  2017 nl-link-stats
# -rwxr-xr-x. 1 root root       11344 Aug  4  2017 nl-list-caches
# -rwxr-xr-x. 1 root root        7232 Aug  4  2017 nl-list-sockets
# -rwxr-xr-x. 1 root root       11464 Aug  4  2017 nl-monitor
# -rwxr-xr-x. 1 root root       11784 Aug  4  2017 nl-neigh-add
# -rwxr-xr-x. 1 root root       11848 Aug  4  2017 nl-neigh-delete
# -rwxr-xr-x. 1 root root       11736 Aug  4  2017 nl-neigh-list
# -rwxr-xr-x. 1 root root       11536 Aug  4  2017 nl-neightbl-list
# -rwxr-xr-x. 2 root root       11632 Aug  4  2017 nl-pktloc-lookup
# -rwxr-xr-x. 2 root root       11880 Aug  4  2017 nl-qdisc-add
# -rwxr-xr-x. 2 root root       11816 Aug  4  2017 nl-qdisc-delete
# -rwxr-xr-x. 2 root root       11904 Aug  4  2017 nl-qdisc-list
# -rwxr-xr-x. 1 root root       12016 Aug  4  2017 nl-route-add
# -rwxr-xr-x. 1 root root       16240 Aug  4  2017 nl-route-delete
# -rwxr-xr-x. 1 root root       11448 Aug  4  2017 nl-route-get
# -rwxr-xr-x. 1 root root       12056 Aug  4  2017 nl-route-list
# -rwxr-xr-x. 1 root root       11568 Aug  4  2017 nl-rule-list
# -rwxr-xr-x. 1 root root       11808 Aug  4  2017 nl-tctree-list
# -rwxr-xr-x. 1 root root        7200 Aug  4  2017 nl-util-addr
# -rwxr-xr-x  1 root root       42392 Feb  5 00:35 nm
# -rwxr-xr-x  1 root root      824456 Feb  5 01:01 nmcli
# -rwxr-xr-x  1 root root       15528 Feb  5 01:01 nm-online
# -rwxr-xr-x  1 root root      658208 Feb  5 01:01 nmtui
# lrwxrwxrwx  1 root root           5 Feb 10 17:59 nmtui-connect -> nmtui
# lrwxrwxrwx  1 root root           5 Feb 10 17:59 nmtui-edit -> nmtui
# lrwxrwxrwx  1 root root           5 Feb 10 17:59 nmtui-hostname -> nmtui
# -rwxr-xr-x  1 root root    16883856 Jun 18  2019 node
# -rwxr-xr-x  1 root root       33200 Aug 20  2019 nohup
# lrwxrwxrwx  1 root root          38 Feb 10 23:15 npm -> ../lib/node_modules/npm/bin/npm-cli.js
# -rwxr-xr-x  1 root root       33144 Aug 20  2019 nproc
# -rwxr-xr-x. 1 root root        3392 Jun 10  2014 nroff
# -rwxr-xr-x  1 root root       28896 Dec  3 01:46 nsenter
# -rwxr-xr-x  1 root root       11472 Dec 11 04:48 nss-policy-check
# -rwxr-xr-x  1 root root        6514 Aug  8  2019 ntpstat
# -rwxr-xr-x  1 root root       66264 Aug 20  2019 numfmt
# -rwxr-xr-x  1 root root      232800 Feb  5 00:35 objcopy
# -rwxr-xr-x  1 root root      366272 Feb  5 00:35 objdump
# -rwxr-xr-x  1 root root       66368 Aug 20  2019 od
# -rwxr-xr-x  1 root root      190880 Oct 31  2018 oldfind
# lrwxrwxrwx  1 root root           6 Feb 10 17:59 open -> openvt
# -rwxr-xr-x  1 root root      555288 Aug  9  2019 openssl
# -rwxr-xr-x  1 root root       20024 Oct 31  2018 openvt
# lrwxrwxrwx  1 root root          22 Feb 10 18:00 orbd -> /etc/alternatives/orbd
# -rwxr-xr-x. 1 root root        5643 Nov  6  2016 os-prober
# lrwxrwxrwx  1 root root          35 Nov 28  2017 osscmd -> /usr/local/aliyun-cli/osscmd/osscmd
# lrwxrwxrwx  1 root root          37 Nov 28  2017 ossutil -> /usr/local/aliyun-cli/ossutil/ossutil
# -rwxr-xr-x. 1 root root       32952 Aug  5  2017 p11-kit
# lrwxrwxrwx  1 root root          25 Feb 10 18:00 pack200 -> /etc/alternatives/pack200
# -rwxr-xr-x  1 root root       17803 Aug  9  2019 package-cleanup
# -rwxr-xr-x  1 root root       11368 Sep 14 02:03 pango-list
# lrwxrwxrwx  1 root root          13 Feb 10 17:59 pango-querymodules-64 -> /usr/bin/true
# -rwxr-xr-x  1 root root       50656 Sep 14 02:03 pango-view
# -rwxr-xr-x  1 root root       11488 Jun 10  2014 paperconf
# -rwxr-xr-x  1 root root        4737 Jun 24  2015 passmass
# -rwsr-xr-x  1 root root       27856 Aug  9  2019 passwd
# -rwxr-xr-x  1 root root       33128 Aug 20  2019 paste
# -rwxr-xr-x  1 root root      150528 Oct 23 07:59 patch
# -rwxr-xr-x  1 root root       33088 Aug 20  2019 pathchk
# lrwxrwxrwx  1 root root          21 Oct 15  2017 pax -> /etc/alternatives/pax
# -rwxr-xr-x. 1 root root        4024 Nov  6  2016 pchrt
# -rwxr-xr-x  1 root root        1950 Aug  3  2017 pcre2-config
# -rwxr-xr-x  1 root root        2138 Aug  2  2017 pcre-config
# -rwxr-xr-x  1 root root      180160 Dec 25  2015 pdcp
# -rwxr-xr-x  1 root root         698 Dec  3 01:54 pdf2dsc
# -rwxr-xr-x  1 root root         909 Dec  3 01:54 pdf2ps
# -rwxr-xr-x  1 root root       16552 Aug  9  2019 pdfdetach
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 pdfetex -> pdftex
# -rwxr-xr-x  1 root root       16008 Aug  9  2019 pdffonts
# -rwxr-xr-x  1 root root       45672 Aug  9  2019 pdfimages
# -rwxr-xr-x  1 root root       28920 Aug  9  2019 pdfinfo
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 pdflatex -> pdftex
# -rwxr-xr-x  1 root root       15888 Aug  9  2019 pdfseparate
# -rwxr-xr-x  1 root root      732632 Oct 31  2018 pdftex
# -rwxr-xr-x  1 root root        1302 Mar 13  2013 pdftexi2dvi
# -rwxr-xr-x  1 root root      123344 Aug  9  2019 pdftocairo
# -rwxr-xr-x  1 root root       92400 Aug  9  2019 pdftohtml
# -rwxr-xr-x  1 root root       20112 Aug  9  2019 pdftoppm
# -rwxr-xr-x  1 root root       20248 Aug  9  2019 pdftops
# -rwxr-xr-x  1 root root       28752 Aug  9  2019 pdftotext
# -rwxr-xr-x  1 root root       20256 Aug  9  2019 pdfunite
# -rwxr-xr-x  1 root root      180160 Dec 25  2015 pdsh
# -rwxr-xr-x  1 root root       11480 Aug  9  2019 peekfd
# -rwxr-xr-x  2 root root       11488 Jan 22  2019 perl
# -rwxr-xr-x  2 root root       11488 Jan 22  2019 perl5.16.3
# -rwxr-xr-x  2 root root       44351 Jan 22  2019 perlbug
# ...
# ---x--s--x  1 root nobody    382216 Aug  9  2019 ssh-agent
# -rwxr-xr-x  1 root root       10469 Aug  9  2019 ssh-copy-id
# -rwxr-xr-x  1 root root       84208 Aug 16  2018 sshfs
# -rwxr-xr-x  1 root root      419208 Aug  9  2019 ssh-keygen
# -rwxr-xr-x  1 root root      441024 Aug  9  2019 ssh-keyscan
# -rwxr-xr-x  1 root root       15736 Sep  8  2017 sshpass
# -rwxr-xr-x  1 root root      112928 Dec 11 04:48 ssltap
# -rwxr-xr-x  1 root root       79040 Aug 20  2019 stat
# -rwxr-xr-x  1 root root       66440 Aug 20  2019 stdbuf
# -rwxr-xr-x  1 root root      650272 Oct 31  2018 strace
# -rwxr-xr-x  1 root root         944 Oct 31  2018 strace-log-merge
# -rwxr-xr-x  1 root root       29112 Feb  5 00:35 strings
# -rwxr-xr-x  1 root root      232800 Feb  5 00:35 strip
# -rwxr-xr-x  1 root root       70256 Aug 20  2019 stty
# -rwsr-xr-x  1 root root       32128 Dec  3 01:46 su
# ---s--x--x  1 root root      147320 Oct 24 23:27 sudo
# lrwxrwxrwx  1 root root           4 Feb 10 17:59 sudoedit -> sudo
# ---x--x--x  1 root root       57456 Oct 24 23:27 sudoreplay
# -rwxr-xr-x  1 root root       37432 Aug 20  2019 sum
# -rwxr-xr-x  3 root root       80872 Jun 10  2014 sx
# -rwxr-xr-x  1 root root       28976 Aug 20  2019 sync
# -rwxr-xr-x  1 root root      717568 Feb  5 00:30 systemctl
# -rwxr-xr-x  1 root root     1558000 Feb  5 00:30 systemd-analyze
# -rwxr-xr-x  1 root root       61824 Feb  5 00:30 systemd-ask-password
# -rwxr-xr-x  1 root root       40952 Feb  5 00:30 systemd-cat
# -rwxr-xr-x  1 root root      334112 Feb  5 00:30 systemd-cgls
# -rwxr-xr-x  1 root root       87128 Feb  5 00:30 systemd-cgtop
# lrwxrwxrwx  1 root root          11 Feb 10 17:59 systemd-coredumpctl -> coredumpctl
# -rwxr-xr-x  1 root root       78680 Feb  5 00:30 systemd-delta
# -rwxr-xr-x  1 root root       40928 Feb  5 00:30 systemd-detect-virt
# -rwxr-xr-x  1 root root       49352 Feb  5 00:30 systemd-escape
# -rwxr-xr-x  1 root root      103952 Feb  5 00:30 systemd-firstboot
# -rwxr-xr-x  1 root root       87344 Feb  5 00:30 systemd-hwdb
# -rwxr-xr-x  1 root root      313200 Feb  5 00:30 systemd-inhibit
# lrwxrwxrwx  1 root root           8 Feb 10 17:59 systemd-loginctl -> loginctl
# -rwxr-xr-x  1 root root       53488 Feb  5 00:30 systemd-machine-id-setup
# -rwxr-xr-x  1 root root       49288 Feb  5 00:30 systemd-notify
# -rwxr-xr-x  1 root root      558912 Feb  5 00:30 systemd-nspawn
# -rwxr-xr-x  1 root root       53416 Feb  5 00:30 systemd-path
# -rwxr-xr-x  1 root root      392216 Feb  5 00:30 systemd-run
# -rwxr-xr-x  1 root root      313136 Feb  5 00:30 systemd-stdio-bridge
# -rwxr-xr-x  1 root root        3979 Feb  5 00:29 systemd-sysv-convert
# -rwxr-xr-x  1 root root      145536 Feb  5 00:30 systemd-tmpfiles
# -rwxr-xr-x  1 root root       86784 Feb  5 00:30 systemd-tty-ask-password-agent
# -rwxr-xr-x  3 root root       80872 Jun 10  2014 sz
# -rwxr-xr-x  1 root root       15680 Sep  7  2017 tabs
# -rwxr-xr-x  1 root root       33264 Aug 20  2019 tac
# -rwxr-xr-x  1 root root       66824 Aug 20  2019 tail
# -rwxr-xr-x  1 root root       24456 Dec  3 01:46 tailf
# -rwxr-xr-x  1 root root       53816 Aug  9  2019 tapestat
# -rwxr-xr-x  1 root root      346136 Oct 31  2018 tar
# -rwxr-xr-x  1 root root       32992 Dec  3 01:46 taskset
# -rwxr-xr-x. 1 root root      118744 Jun 10  2014 tbl
# lrwxrwxrwx  1 root root           8 Nov  2  2017 tclsh -> tclsh8.5
# -rwxr-xr-x  1 root root        7168 Nov 20  2015 tclsh8.5
# -rwxr-xr-x  1 root root      154648 Aug  9  2019 teamd
# -rwxr-xr-x  1 root root       29672 Aug  9  2019 teamdctl
# -rwxr-xr-x  1 root root       19560 Aug  9  2019 teamnl
# -rwxr-xr-x  1 root root       11432 Jun 10  2014 teckit_compile
# -rwxr-xr-x  1 root root       33160 Aug 20  2019 tee
# -rwxr-xr-x  1 root root      101776 Aug  4  2017 telnet
# -rwxr-xr-x  1 root root       37336 Aug 20  2019 test
# -rwxr-xr-x. 1 root root       30488 Jun 10  2014 testgdbm
# -rwxr-xr-x  1 root root      320952 Oct 31  2018 tex
# lrwxrwxrwx  1 root root          51 Feb 10 18:07 texconfig -> /usr/share/texlive/texmf/scripts/tetex/texconfig.sh
# lrwxrwxrwx  1 root root          58 Feb 10 18:08 texconfig-dialog -> /usr/share/texlive/texmf/scripts/tetex/texconfig-dialog.sh
# lrwxrwxrwx  1 root root          55 Feb 10 18:08 texconfig-sys -> /usr/share/texlive/texmf/scripts/tetex/texconfig-sys.sh
# lrwxrwxrwx  1 root root           8 Feb 10 18:07 texhash -> mktexlsr
# -rwxr-xr-x  1 root root       52045 Apr 11  2018 texi2any
# -rwxr-xr-x  1 root root       58067 Mar 13  2013 texi2dvi
# -rwxr-xr-x  1 root root        1302 Mar 13  2013 texi2pdf
# -rwxr-xr-x  1 root root       20424 Apr 11  2018 texindex
# lrwxrwxrwx  1 root root          50 Feb 10 18:08 texlinks -> /usr/share/texlive/texmf/scripts/tetex/texlinks.sh
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 texlua -> luatex
# lrwxrwxrwx  1 root root           6 Feb 10 18:08 texluac -> luatex
# lrwxrwxrwx  1 root root          58 Feb 10 18:07 thumbpdf -> /usr/share/texlive/texmf-dist/scripts/thumbpdf/thumbpdf.pl
# -rwxr-xr-x  1 root root       65800 Sep  7  2017 tic
# -rwxr-xr-x  1 root root       15920 Jun 12  2014 time
# -rwxr-xr-x  1 root root      338104 Feb  5 00:30 timedatectl
# -rwxr-xr-x  1 root root         303 Jun 24  2015 timed-read
# -rwxr-xr-x  1 root root         277 Jun 24  2015 timed-run
# -rwxr-xr-x  1 root root       54592 Aug 20  2019 timeout
# -rwxr-xr-x  1 root root       15744 Oct 19 00:08 tload
# -rwxr-xr-x  1 root root       31856 Feb  5 07:13 tmon
# -rwxr-xr-x  1 root root      631736 May 25  2019 tmux
# lrwxrwxrwx  1 root root          27 Feb 10 18:00 tnameserv -> /etc/alternatives/tnameserv
# -rwxr-xr-x  1 root root       15800 Sep  7  2017 toe
# -rwxr-xr-x  1 root root      106880 Oct 19 00:08 top
# -rwxr-xr-x  1 root root       62480 Aug 20  2019 touch
# -rwxr-xr-x  1 root root       15784 Sep  7  2017 tput
# -rwxr-xr-x  1 root root         213 Jan 28  2018 tqdm
# -rwxr-xr-x  1 root root       45680 Aug 20  2019 tr
# -rwxr-xr-x. 1 root root       15408 Aug  4  2017 tracepath
# -rwxr-xr-x. 1 root root       15408 Aug  4  2017 tracepath6
# -rwxr-xr-x  1 root root       62768 Jun 10  2014 tree
# -rwxr-xr-x. 1 root root      525272 Jun 10  2014 troff
# -rwxr-xr-x  1 root root       28936 Aug 20  2019 true
# -rwxr-xr-x  1 root root       53936 Aug 20  2019 truncate
# -rwxr-xr-x. 1 root root      183376 Aug  5  2017 trust
# -rwxr-xr-x  1 root root       20072 Sep  7  2017 tset
# -rwxr-xr-x  1 root root       37344 Aug 20  2019 tsort
# -rwxr-xr-x  1 root root      101416 Nov 20  2015 ttmkfdir
# -rwxr-xr-x  1 root root       28968 Aug 20  2019 tty
# -rwxr-xr-x  1 root root      115864 Feb  5 07:13 turbostat
# -rwxr-xr-x  1 root root       15576 Jun 10  2014 txtconv
# -rwxr-xr-x  1 root root        7339 Aug  7  2019 tzselect
# -rwxr-xr-x  1 root root       19936 Oct 31  2018 ucs2any
# -rwxr-xr-x  1 root root      424208 Feb  5 00:30 udevadm
# -rwxr-xr-x  1 root root       19936 Dec  3 01:46 ul
# -rwxr-xr-x  1 root root       15472 Oct 31  2018 ulockmgr_server
# -rwxr-xr-x  1 root root          29 Aug  8  2019 umask
# -rwsr-xr-x  1 root root       31984 Dec  3 01:46 umount
# -rwxr-xr-x  1 root root          31 Aug  8  2019 unalias
# -rwxr-xr-x  1 root root       33080 Aug 20  2019 uname
# -rwxr-xr-x  1 root root     2343960 Jun 10  2016 unar
# -rwxr-xr-x  1 root root         640 Jun 24  2015 unbuffer
# -rwxr-xr-x  1 root root       33232 Aug 20  2019 unexpand
# -rwxr-xr-x  1 root root        2555 Oct 31  2018 unicode_start
# -rwxr-xr-x  1 root root         363 Oct 31  2018 unicode_stop
# -rwxr-xr-x  1 root root       45784 Aug 20  2019 uniq
# -rwxr-xr-x  1 root root        4165 Dec  3 01:54 unix-lpr.sh
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 unlink
# lrwxrwxrwx  1 root root           3 Jan 14 09:55 unlz4 -> lz4
# lrwxrwxrwx  1 root root          27 Feb 10 18:00 unpack200 -> /etc/alternatives/unpack200
# -rwxr-xr-x  1 root root       15824 Dec  3 01:46 unshare
# lrwxrwxrwx. 1 root root           2 Oct 15  2017 unxz -> xz
# -rwxr-xr-x  2 root root      185472 Aug  9  2019 unzip
# -rwxr-xr-x  1 root root       90752 Aug  9  2019 unzipsfx
# -rwxr-xr-x  1 root root        1054 Nov 27 23:33 update-ca-trust
# -rwxr-xr-x  1 root root       48792 Apr 11  2018 updatedb
# -rwxr-xr-x  1 root root       20168 Aug  9  2019 update-desktop-database
# -rwxr-xr-x  1 root root         313 Aug  2  2017 update-gtk-immodules
# -rwxr-xr-x  1 root root       54080 Apr 11  2018 update-mime-database
# lrwxrwxrwx  1 root root          53 Feb 10 18:08 updmap -> /usr/share/texlive/texmf-dist/scripts/tetex/updmap.pl
# lrwxrwxrwx  1 root root          57 Feb 10 18:08 updmap-sys -> /usr/share/texlive/texmf-dist/scripts/tetex/updmap-sys.sh
# -rwxr-xr-x  1 root root       11488 Oct 19 00:08 uptime
# -rwxr-xr-x  1 root root       12465 Oct 31  2018 urlgrabber
# -rwxr-xr-x  1 root root       33200 Aug 20  2019 users
# -rwxr-xr-x  1 root root       11208 Aug  9  2019 usleep
# -rwxr-xr-x. 1 root root       15776 Nov  6  2016 usx2yloader
# -rwxr-xr-x  1 root root       15816 Dec  3 01:46 utmpdump
# -rwxr-xr-x  1 root root       15328 Sep 14 02:05 uuclient
# -rwxr-xr-x  1 root root       11480 Dec  3 01:46 uuidgen
# -rwxr-xr-x  1 root root      117608 Aug 20  2019 vdir
# -rwxr-xr-x  1 root root       11046 Aug  9  2019 verifytree
# -rwxr-xr-x  1 root root      928184 Aug  9  2019 vi
# lrwxrwxrwx  1 root root           2 Feb 10 17:59 view -> vi
# -rwxr-xr-x  1 root root     2337192 Aug  9  2019 vim
# lrwxrwxrwx  1 root root           3 Feb 10 17:59 vimdiff -> vim
# -rwxr-xr-x  1 root root        2084 Aug  9  2019 vimtutor
# -rwxr-xr-x  1 root root         213 Jan 29  2018 virtualenv
# -rwxr-xr-x  1 root root       16160 Oct 31  2018 vlock
# -rwxr-xr-x  1 root root       32232 Oct 19 00:08 vmstat
# -rwxr-xr-x. 1 root root       15744 Nov  6  2016 vxloader
# -rwxr-xr-x  1 root root       19912 Oct 19 00:08 w
# -rwxr-xr-x  1 root root          28 Aug  8  2019 wait
# -r-xr-sr-x. 1 root tty        15344 Jun 10  2014 wall
# -rwxr-xr-x  1 root root       24728 Oct 19 00:08 watch
# -rwxr-xr-x  1 root root       15720 Jul 13  2018 watchgnupg
# -rwxr-xr-x  1 root root       41648 Aug 20  2019 wc
# -rwxr-xr-x  1 root root       41672 Dec  3 01:46 wdctl
# -rwxr-xr-x  1 root root        2237 Jun 24  2015 weather
# -rwxr-xr-x  1 root root      418776 May 16  2019 wget
# -rwxr-xr-x  1 root root       46584 Oct 31  2018 whatis
# lrwxrwxrwx  1 root root           7 Feb 10 18:00 wheel -> wheel-2
# lrwxrwxrwx  1 root root           9 Feb 10 18:00 wheel-2 -> wheel-2.7
# -rwxr-xr-x  1 root root         295 Aug  8  2019 wheel-2.7
# -rwxr-xr-x  1 root root       20680 Dec  3 01:46 whereis
# -rwxr-xr-x. 1 root root       24336 Jun 10  2014 which
# -rwxr-xr-x. 1 root root       28504 Jun 10  2014 whiptail
# -rwxr-xr-x  1 root root       49872 Aug 20  2019 who
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 whoami
# lrwxrwxrwx  1 root root           7 Feb 10 18:07 wish -> wish8.5
# -rwxr-xr-x  1 root root        7208 Nov 20  2015 wish8.5
# -rwxr-xr-x  1 root root         229 Nov  6  2016 withsctp
# -rwxr-sr-x  1 root tty        19544 Dec  3 01:46 write
# lrwxrwxrwx  1 root root          23 Feb 10 18:00 wsgen -> /etc/alternatives/wsgen
# lrwxrwxrwx  1 root root          26 Feb 10 18:00 wsimport -> /etc/alternatives/wsimport
# lrwxrwxrwx  1 root root           7 Feb 10 17:59 x86_64 -> setarch
# -rwxr-xr-x  4 root root      772744 Aug  7  2019 x86_64-redhat-linux-c++
# -rwxr-xr-x  4 root root      772744 Aug  7  2019 x86_64-redhat-linux-g++
# -rwxr-xr-x  2 root root      768648 Aug  7  2019 x86_64-redhat-linux-gcc
# -rwxr-xr-x  1 root root       10480 Feb  5 07:13 x86_energy_perf_policy
# -rwxr-xr-x  1 root root       62368 Oct 31  2018 xargs
# -rwxr-xr-x  1 root root       19511 Nov  5  2016 xdg-desktop-icon
# -rwxr-xr-x  1 root root       42913 Nov  5  2016 xdg-desktop-menu
# -rwxr-xr-x  1 root root       23964 Nov  5  2016 xdg-email
# -rwxr-xr-x  1 root root       28727 Nov  5  2016 xdg-icon-resource
# -rwxr-xr-x  1 root root       39354 Nov  5  2016 xdg-mime
# -rwxr-xr-x  1 root root       19296 Nov  5  2016 xdg-open
# -rwxr-xr-x  1 root root       28532 Nov  5  2016 xdg-screensaver
# -rwxr-xr-x  1 root root       33576 Nov  5  2016 xdg-settings
# -rwxr-xr-x  1 root root        1863 Oct 31  2018 xdvi
# -rwxr-xr-x  1 root root      648120 Oct 31  2018 xdvipdfmx
# -rwxr-xr-x  1 root root      642520 Oct 31  2018 xdvi-xaw
# lrwxrwxrwx  1 root root           5 Feb 11 18:40 xelatex -> xetex
# -rwxr-xr-x  1 root root      558040 Oct 31  2018 xetex
# -rwxr-xr-x  1 root root       11416 Aug 12  2017 xgamma
# -rwxr-xr-x. 1 root root      271784 Aug  3  2017 xgettext
# -rwxr-xr-x  1 root root       15752 Aug 12  2017 xhost
# -rwxr-xr-x  1 root root       54080 Aug 12  2017 xinput
# lrwxrwxrwx  1 root root          21 Feb 10 18:00 xjc -> /etc/alternatives/xjc
# -rwxr-xr-x  1 root root        4862 Jun 24  2015 xkibitz
# -rwxr-xr-x  1 root root       15632 Aug 12  2017 xkill
# -rwxr-xr-x. 1 root root       19752 Jun 23  2016 xmlcatalog
# -rwxr-xr-x. 1 root root       63408 Jun 23  2016 xmllint
# -rwxr-xr-x. 1 root root       24568 Nov 29  2016 xmlwf
# -rwxr-xr-x  1 root root       33056 Aug 12  2017 xmodmap
# -rwxr-xr-x  1 root root        1063 Nov 21  2015 xmvn-builddep
# -rwxr--r--  1 root root        1322 Oct 31  2018 xorg-x11-fonts-update-dirs
# -rwxr-xr-x  1 root root       61504 Aug 12  2017 xrandr
# -rwxr-xr-x  1 root root       28448 Aug 12  2017 xrdb
# -rwxr-xr-x  1 root root       11424 Aug 12  2017 xrefresh
# -rwxr-xr-x  1 root root       32480 Aug 12  2017 xset
# -rwxr-xr-x  1 root root       11368 Aug 12  2017 xsetmode
# -rwxr-xr-x  1 root root       11400 Aug 12  2017 xsetpointer
# -rwxr-xr-x  1 root root       19840 Aug 12  2017 xsetroot
# -rwxr-xr-x  1 root root       24056 Jun 10  2014 xsltproc
# -rwxr-xr-x  1 root root       16144 Aug 12  2017 xstdcmap
# -rwxr-xr-x  1 root root       14768 Aug  9  2019 xxd
# -rwxr-xr-x. 1 root root       75280 Nov  5  2016 xz
# lrwxrwxrwx. 1 root root           2 Oct 15  2017 xzcat -> xz
# lrwxrwxrwx. 1 root root           6 Oct 15  2017 xzcmp -> xzdiff
# -rwxr-xr-x. 1 root root       11472 Nov  5  2016 xzdec
# -rwxr-xr-x. 1 root root        6632 Nov  5  2016 xzdiff
# lrwxrwxrwx. 1 root root           6 Oct 15  2017 xzegrep -> xzgrep
# lrwxrwxrwx. 1 root root           6 Oct 15  2017 xzfgrep -> xzgrep
# -rwxr-xr-x. 1 root root        5628 Nov  5  2016 xzgrep
# -rwxr-xr-x. 1 root root        1802 Nov  5  2016 xzless
# -rwxr-xr-x. 1 root root        2161 Nov  5  2016 xzmore
# -rwxr-xr-x  1 root root       28984 Aug 20  2019 yes
# lrwxrwxrwx  1 root root           8 Feb 10 17:59 ypdomainname -> hostname
# -rwxr-xr-x  1 root root         801 Aug  8  2019 yum
# -rwxr-xr-x  1 root root       10189 Aug  9  2019 yum-builddep
# -rwxr-xr-x  1 root root        9579 Aug  9  2019 yum-config-manager
# -rwxr-xr-x  1 root root        8538 Aug  9  2019 yum-debug-dump
# -rwxr-xr-x  1 root root        7903 Aug  9  2019 yum-debug-restore
# -rwxr-xr-x  1 root root       11115 Aug  9  2019 yumdownloader
# -rwxr-xr-x  1 root root       11031 Aug  9  2019 yum-groups-manager
# -rwxr-xr-x  1 root root        1941 Apr 11  2018 zcat
# -rwxr-xr-x  1 root root        1760 Apr 11  2018 zcmp
# -rwxr-xr-x  1 root root        5768 Apr 11  2018 zdiff
# -rwxr-xr-x  1 root root         123 Apr 11  2018 zegrep
# lrwxrwxrwx  1 root root          25 Nov  2  2017 zf -> /usr/share/php/Zend/zf.sh
# -rwxr-xr-x  1 root root         123 Apr 11  2018 zfgrep
# -rwxr-xr-x  1 root root        2144 Apr 11  2018 zforce
# -rwxr-xr-x  1 root root        6132 Apr 11  2018 zgrep
# -rwxr-xr-x  1 root root      215840 Nov  6  2016 zip
# -rwxr-xr-x  1 root root      100456 Nov  6  2016 zipcloak
# -rwxr-xr-x  1 root root       11992 Jun 10  2014 zipcmp
# -rwxr-xr-x  1 root root       48451 Jun 10  2014 zipdetails
# -rwxr-xr-x  1 root root        2953 Oct 11  2008 zipgrep
# -rwxr-xr-x  2 root root      185472 Aug  9  2019 zipinfo
# -rwxr-xr-x  1 root root       12040 Jun 10  2014 zipmerge
# -rwxr-xr-x  1 root root       95984 Nov  6  2016 zipnote
# -rwxr-xr-x  1 root root      100096 Nov  6  2016 zipsplit
# -rwxr-xr-x  1 root root       11880 Jun 10  2014 ziptorrent
# -rwxr-xr-x  1 root root        2041 Apr 11  2018 zless
# -rwxr-xr-x  1 root root        2859 Apr 11  2018 zmore
# -rwxr-xr-x  1 root root        5343 Apr 11  2018 znew
# lrwxrwxrwx. 1 root root           6 Oct 15  2017 zsoelim -> soelim

# %%
cat ls-output.txt ls-error.txt > ls_all.txt

# %%
ls -htla ls_all.txt
# Out:
# -rw-rw-r-- 1 lifeng lifeng 153K Feb 26 22:01 ls_all.txt

# %% [markdown]
# ## Pipelines
#
# Read data from standard input and send to standard output is utilized by a shell feature called pipelines with the format
#
#
#            command1 | command2

# %%
ls -l /usr/bin | wc
# Out:
#    1270   11799   78060

# %%
ls /bin /usr/bin | sort | head
# Out:
# [
# [
# a2p
# a2p
# ab
# ab
# abs2rel
# abs2rel
# addr2line
# sort: write failed: standard output: Broken pipe
# sort: write error
